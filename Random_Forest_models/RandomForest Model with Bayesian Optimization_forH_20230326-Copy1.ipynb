# %%
# Import libraries
import pandas as pd
import numpy as np
import datetime
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

# %%
# !pip3 install tsfresh
# Out:
# Requirement already satisfied: tsfresh in /home/kimura/.local/lib/python3.10/site-packages (0.20.0)
# Requirement already satisfied: pandas>=0.25.0 in /home/kimura/.local/lib/python3.10/site-packages (from tsfresh) (2.0.2)
# Requirement already satisfied: patsy>=0.4.1 in /home/kimura/.local/lib/python3.10/site-packages (from tsfresh) (0.5.3)
# Requirement already satisfied: statsmodels>=0.13 in /home/kimura/.local/lib/python3.10/site-packages (from tsfresh) (0.14.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /home/kimura/.local/lib/python3.10/site-packages (from tsfresh) (1.2.2)
# Requirement already satisfied: dask[dataframe]>=2.9.0 in /home/kimura/.local/lib/python3.10/site-packages (from tsfresh) (2023.5.1)
# Requirement already satisfied: cloudpickle in /home/kimura/.local/lib/python3.10/site-packages (from tsfresh) (2.2.1)
# Requirement already satisfied: requests>=2.9.1 in /home/kimura/.local/lib/python3.10/site-packages (from tsfresh) (2.31.0)
# Requirement already satisfied: distributed>=2.11.0 in /home/kimura/.local/lib/python3.10/site-packages (from tsfresh) (2023.5.1)
# Requirement already satisfied: scipy>=1.2.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from tsfresh) (1.10.0)
# Requirement already satisfied: numpy>=1.15.1 in /home/kimura/anaconda3/lib/python3.10/site-packages (from tsfresh) (1.23.5)
# Requirement already satisfied: stumpy>=1.7.2 in /home/kimura/.local/lib/python3.10/site-packages (from tsfresh) (1.11.1)
# Requirement already satisfied: tqdm>=4.10.0 in /home/kimura/.local/lib/python3.10/site-packages (from tsfresh) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (22.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/kimura/.local/lib/python3.10/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (2023.5.0)
# Requirement already satisfied: click>=8.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (8.0.4)
# Requirement already satisfied: partd>=1.2.0 in /home/kimura/.local/lib/python3.10/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (1.4.0)
# Requirement already satisfied: toolz>=0.10.0 in /home/kimura/.local/lib/python3.10/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/kimura/.local/lib/python3.10/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (6.6.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/kimura/anaconda3/lib/python3.10/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (6.0)
# Requirement already satisfied: urllib3>=1.24.3 in /home/kimura/anaconda3/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (1.26.14)
# Requirement already satisfied: tornado>=6.0.4 in /home/kimura/anaconda3/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (6.1)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /home/kimura/.local/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (2.4.0)
# Requirement already satisfied: psutil>=5.7.2 in /home/kimura/.local/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (5.9.5)
# Requirement already satisfied: tblib>=1.6.0 in /home/kimura/.local/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (1.7.0)
# Requirement already satisfied: zict>=2.2.0 in /home/kimura/.local/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (3.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in /home/kimura/anaconda3/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /home/kimura/.local/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /home/kimura/.local/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kimura/.local/lib/python3.10/site-packages (from pandas>=0.25.0->tsfresh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/kimura/anaconda3/lib/python3.10/site-packages (from pandas>=0.25.0->tsfresh) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /home/kimura/.local/lib/python3.10/site-packages (from pandas>=0.25.0->tsfresh) (2023.3)
# Requirement already satisfied: six in /home/kimura/anaconda3/lib/python3.10/site-packages (from patsy>=0.4.1->tsfresh) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/kimura/.local/lib/python3.10/site-packages (from requests>=2.9.1->tsfresh) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/kimura/anaconda3/lib/python3.10/site-packages (from requests>=2.9.1->tsfresh) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kimura/anaconda3/lib/python3.10/site-packages (from requests>=2.9.1->tsfresh) (2023.5.7)
# Requirement already satisfied: joblib>=1.1.1 in /home/kimura/.local/lib/python3.10/site-packages (from scikit-learn>=0.22.0->tsfresh) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/kimura/.local/lib/python3.10/site-packages (from scikit-learn>=0.22.0->tsfresh) (3.1.0)
# Requirement already satisfied: numba>=0.54 in /home/kimura/.local/lib/python3.10/site-packages (from stumpy>=1.7.2->tsfresh) (0.57.0)
# Requirement already satisfied: zipp>=0.5 in /home/kimura/anaconda3/lib/python3.10/site-packages (from importlib-metadata>=4.13.0->dask[dataframe]>=2.9.0->tsfresh) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from jinja2>=2.10.3->distributed>=2.11.0->tsfresh) (2.1.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /home/kimura/.local/lib/python3.10/site-packages (from numba>=0.54->stumpy>=1.7.2->tsfresh) (0.40.0)

# %%
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute

# %%
# !pip install bayesian-optimization
# Out:
# Requirement already satisfied: bayesian-optimization in /home/kimura/.local/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: numpy>=1.9.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from bayesian-optimization) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.18.0 in /home/kimura/.local/lib/python3.10/site-packages (from bayesian-optimization) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from bayesian-optimization) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/kimura/.local/lib/python3.10/site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/kimura/.local/lib/python3.10/site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.2.0)

# %%
from pprint import pprint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from bayes_opt import BayesianOptimization

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
 # read the csv files
df_features = pd.read_csv("1677CVEs_783dim_features_20230326.csv")
df_features.rename({"Unnamed: 0" : "CVE"}, inplace = True, axis = 1)
df_features.set_index('CVE', inplace = True)
df_features
# Out:
#                 count__variance_larger_than_standard_deviation  \
# CVE
# CVE-2006-10001                                             1.0
# CVE-2008-10002                                             0.0
# CVE-2008-10003                                             1.0
# CVE-2008-10004                                             1.0
# CVE-2011-10002                                             1.0
# ...                                                        ...
# CVE-2023-28685                                             0.0
# CVE-2023-28686                                             1.0
# CVE-2023-28708                                             1.0
# CVE-2023-28725                                             1.0
# CVE-2023-28818                                             1.0
#
#                 count__has_duplicate_max  count__has_duplicate_min  \
# CVE
# CVE-2006-10001                       0.0                       1.0
# CVE-2008-10002                       1.0                       1.0
# CVE-2008-10003                       0.0                       1.0
# CVE-2008-10004                       0.0                       1.0
# CVE-2011-10002                       0.0                       1.0
# ...                                  ...                       ...
# CVE-2023-28685                       0.0                       1.0
# CVE-2023-28686                       1.0                       1.0
# CVE-2023-28708                       0.0                       1.0
# CVE-2023-28725                       0.0                       0.0
# CVE-2023-28818                       1.0                       0.0
#
#                 count__has_duplicate  count__sum_values  count__abs_energy  \
# CVE
# CVE-2006-10001                   1.0               16.0               60.0
# CVE-2008-10002                   1.0               15.0               37.0
# CVE-2008-10003                   1.0               16.0               44.0
# CVE-2008-10004                   1.0               20.0              110.0
# CVE-2011-10002                   1.0               12.0               54.0
# ...                              ...                ...                ...
# CVE-2023-28685                   1.0               15.0               35.0
# CVE-2023-28686                   1.0               15.0               43.0
# CVE-2023-28708                   1.0               30.0              100.0
# CVE-2023-28725                   1.0               15.0               61.0
# CVE-2023-28818                   1.0               13.0               41.0
#
#                 count__mean_abs_change  count__mean_change  \
# CVE
# CVE-2006-10001                2.000000           -0.400000
# CVE-2008-10002                1.333333           -0.333333
# CVE-2008-10003                1.000000           -0.333333
# CVE-2008-10004                4.000000           -0.333333
# CVE-2011-10002                2.333333           -1.000000
# ...                                ...                 ...
# CVE-2023-28685                1.285714           -0.142857
# CVE-2023-28686                1.666667            0.000000
# CVE-2023-28708                1.692308           -0.153846
# CVE-2023-28725                2.250000           -0.250000
# CVE-2023-28818                2.250000           -0.250000
#
#                 count__mean_second_derivative_central  count__median  ...  \
# CVE                                                                   ...
# CVE-2006-10001                               0.125000            2.5  ...
# CVE-2008-10002                               0.100000            2.0  ...
# CVE-2008-10003                              -0.100000            2.0  ...
# CVE-2008-10004                               0.200000            1.0  ...
# CVE-2011-10002                              -0.500000            2.5  ...
# ...                                               ...            ...  ...
# CVE-2023-28685                               0.000000            2.0  ...
# CVE-2023-28686                              -0.100000            2.0  ...
# CVE-2023-28708                              -0.125000            1.0  ...
# CVE-2023-28725                              -0.500000            2.0  ...
# CVE-2023-28818                              -0.833333            2.0  ...
#
#                 count__fourier_entropy__bins_5  \
# CVE
# CVE-2006-10001                        1.039721
# CVE-2008-10002                        1.039721
# CVE-2008-10003                        1.386294
# CVE-2008-10004                        1.039721
# CVE-2011-10002                        1.098612
# ...                                        ...
# CVE-2023-28685                        1.332179
# CVE-2023-28686                        1.039721
# CVE-2023-28708                        1.494175
# CVE-2023-28725                        1.098612
# CVE-2023-28818                        0.636514
#
#                 count__fourier_entropy__bins_10  \
# CVE
# CVE-2006-10001                         1.039721
# CVE-2008-10002                         1.039721
# CVE-2008-10003                         1.386294
# CVE-2008-10004                         1.386294
# CVE-2011-10002                         1.098612
# ...                                         ...
# CVE-2023-28685                         1.332179
# CVE-2023-28686                         1.039721
# CVE-2023-28708                         1.732868
# CVE-2023-28725                         1.098612
# CVE-2023-28818                         0.636514
#
#                 count__fourier_entropy__bins_100  \
# CVE
# CVE-2006-10001                          1.386294
# CVE-2008-10002                          1.039721
# CVE-2008-10003                          1.386294
# CVE-2008-10004                          1.386294
# CVE-2011-10002                          1.098612
# ...                                          ...
# CVE-2023-28685                          1.609438
# CVE-2023-28686                          1.386294
# CVE-2023-28708                          1.906155
# CVE-2023-28725                          1.098612
# CVE-2023-28818                          1.098612
#
#                 count__permutation_entropy__dimension_3__tau_1  \
# CVE
# CVE-2006-10001                                        1.386294
# CVE-2008-10002                                        1.054920
# CVE-2008-10003                                        1.332179
# CVE-2008-10004                                        1.054920
# CVE-2011-10002                                        0.693147
# ...                                                        ...
# CVE-2023-28685                                        1.329661
# CVE-2023-28686                                        1.609438
# CVE-2023-28708                                        1.329661
# CVE-2023-28725                                        1.098612
# CVE-2023-28818                                        1.098612
#
#                 count__permutation_entropy__dimension_4__tau_1  \
# CVE
# CVE-2006-10001                                        1.098612
# CVE-2008-10002                                        1.039721
# CVE-2008-10003                                        1.386294
# CVE-2008-10004                                        1.039721
# CVE-2011-10002                                       -0.000000
# ...                                                        ...
# CVE-2023-28685                                        1.609438
# CVE-2023-28686                                        1.386294
# CVE-2023-28708                                        1.893788
# CVE-2023-28725                                        0.693147
# CVE-2023-28818                                        0.693147
#
#                 count__permutation_entropy__dimension_5__tau_1  \
# CVE
# CVE-2006-10001                                        0.693147
# CVE-2008-10002                                        1.098612
# CVE-2008-10003                                        1.098612
# CVE-2008-10004                                        1.098612
# CVE-2011-10002                                             NaN
# ...                                                        ...
# CVE-2023-28685                                        1.386294
# CVE-2023-28686                                        1.098612
# CVE-2023-28708                                        2.302585
# CVE-2023-28725                                       -0.000000
# CVE-2023-28818                                       -0.000000
#
#                 count__permutation_entropy__dimension_6__tau_1  \
# CVE
# CVE-2006-10001                                       -0.000000
# CVE-2008-10002                                        0.693147
# CVE-2008-10003                                        0.693147
# CVE-2008-10004                                        0.693147
# CVE-2011-10002                                             NaN
# ...                                                        ...
# CVE-2023-28685                                        1.098612
# CVE-2023-28686                                        0.693147
# CVE-2023-28708                                        2.197225
# CVE-2023-28725                                             NaN
# CVE-2023-28818                                             NaN
#
#                 count__permutation_entropy__dimension_7__tau_1  \
# CVE
# CVE-2006-10001                                             NaN
# CVE-2008-10002                                       -0.000000
# CVE-2008-10003                                       -0.000000
# CVE-2008-10004                                       -0.000000
# CVE-2011-10002                                             NaN
# ...                                                        ...
# CVE-2023-28685                                        0.693147
# CVE-2023-28686                                       -0.000000
# CVE-2023-28708                                        2.079442
# CVE-2023-28725                                             NaN
# CVE-2023-28818                                             NaN
#
#                 count__query_similarity_count__query_None__threshold_0.0  \
# CVE
# CVE-2006-10001                                                NaN
# CVE-2008-10002                                                NaN
# CVE-2008-10003                                                NaN
# CVE-2008-10004                                                NaN
# CVE-2011-10002                                                NaN
# ...                                                           ...
# CVE-2023-28685                                                NaN
# CVE-2023-28686                                                NaN
# CVE-2023-28708                                                NaN
# CVE-2023-28725                                                NaN
# CVE-2023-28818                                                NaN
#
#                 count__mean_n_absolute_max__number_of_maxima_7
# CVE
# CVE-2006-10001                                             NaN
# CVE-2008-10002                                             NaN
# CVE-2008-10003                                             NaN
# CVE-2008-10004                                             NaN
# CVE-2011-10002                                             NaN
# ...                                                        ...
# CVE-2023-28685                                        2.000000
# CVE-2023-28686                                             NaN
# CVE-2023-28708                                        3.285714
# CVE-2023-28725                                             NaN
# CVE-2023-28818                                             NaN
#
# [1677 rows x 783 columns]

# %%
df_flag = pd.read_csv("CVE_list_with_flagH_20230326.csv", index_col = ['CVE'] )
df_flag_sorted = df_flag.sort_values('CVE')
df_flag_sorted.drop('Unnamed: 0', inplace = True, axis = 1)
df_flag_sorted
# Out:
#                 flag_H
# CVE
# CVE-2006-10001       0
# CVE-2008-10002       0
# CVE-2008-10003       1
# CVE-2008-10004       1
# CVE-2011-10002       1
# ...                ...
# CVE-2023-28685       1
# CVE-2023-28686       1
# CVE-2023-28708       0
# CVE-2023-28725       1
# CVE-2023-28818       0
#
# [1677 rows x 1 columns]

# %% [markdown]
# ## Filter the features which are NaN

# %%
df_features = impute(df_features)
df_features
# Out:
# /home/kimura/.local/lib/python3.10/site-packages/tsfresh/utilities/dataframe_functions.py:198: RuntimeWarning: The columns ['count__fft_coefficient__attr_"real"__coeff_25'
#  'count__fft_coefficient__attr_"real"__coeff_26'
#  'count__fft_coefficient__attr_"real"__coeff_27'
#  'count__fft_coefficient__attr_"real"__coeff_28'
#  'count__fft_coefficient__attr_"real"__coeff_29'
#  'count__fft_coefficient__attr_"real"__coeff_30'
#  'count__fft_coefficient__attr_"real"__coeff_31'
#  'count__fft_coefficient__attr_"real"__coeff_32'
#  'count__fft_coefficient__attr_"real"__coeff_33'
#  'count__fft_coefficient__attr_"real"__coeff_34'
#  'count__fft_coefficient__attr_"real"__coeff_35'
#  'count__fft_coefficient__attr_"real"__coeff_36'
#  'count__fft_coefficient__attr_"real"__coeff_37'
#  'count__fft_coefficient__attr_"real"__coeff_38'
#  'count__fft_coefficient__attr_"real"__coeff_39'
#  'count__fft_coefficient__attr_"real"__coeff_40'
#  'count__fft_coefficient__attr_"real"__coeff_41'
#  'count__fft_coefficient__attr_"real"__coeff_42'
#  'count__fft_coefficient__attr_"real"__coeff_43'
#  'count__fft_coefficient__attr_"real"__coeff_44'
#  'count__fft_coefficient__attr_"real"__coeff_45'
#  'count__fft_coefficient__attr_"real"__coeff_46'
#  'count__fft_coefficient__attr_"real"__coeff_47'
#  'count__fft_coefficient__attr_"real"__coeff_48'
#  'count__fft_coefficient__attr_"real"__coeff_49'
#  'count__fft_coefficient__attr_"real"__coeff_50'
#  'count__fft_coefficient__attr_"real"__coeff_51'
#  'count__fft_coefficient__attr_"real"__coeff_52'
#  'count__fft_coefficient__attr_"real"__coeff_53'
#  'count__fft_coefficient__attr_"real"__coeff_54'
#  'count__fft_coefficient__attr_"real"__coeff_55'
#  'count__fft_coefficient__attr_"real"__coeff_56'
#  'count__fft_coefficient__attr_"real"__coeff_57'
#  'count__fft_coefficient__attr_"real"__coeff_58'
#  'count__fft_coefficient__attr_"real"__coeff_59'
#  'count__fft_coefficient__attr_"real"__coeff_60'
#  'count__fft_coefficient__attr_"real"__coeff_61'
#  'count__fft_coefficient__attr_"real"__coeff_62'
#  'count__fft_coefficient__attr_"real"__coeff_63'
#  'count__fft_coefficient__attr_"real"__coeff_64'
#  'count__fft_coefficient__attr_"real"__coeff_65'
#  'count__fft_coefficient__attr_"real"__coeff_66'
#  'count__fft_coefficient__attr_"real"__coeff_67'
#  'count__fft_coefficient__attr_"real"__coeff_68'
#  'count__fft_coefficient__attr_"real"__coeff_69'
#  'count__fft_coefficient__attr_"real"__coeff_70'
#  'count__fft_coefficient__attr_"real"__coeff_71'
#  'count__fft_coefficient__attr_"real"__coeff_72'
#  'count__fft_coefficient__attr_"real"__coeff_73'
#  'count__fft_coefficient__attr_"real"__coeff_74'
#  'count__fft_coefficient__attr_"real"__coeff_75'
#  'count__fft_coefficient__attr_"real"__coeff_76'
#  'count__fft_coefficient__attr_"real"__coeff_77'
#  'count__fft_coefficient__attr_"real"__coeff_78'
#  'count__fft_coefficient__attr_"real"__coeff_79'
#  'count__fft_coefficient__attr_"real"__coeff_80'
#  'count__fft_coefficient__attr_"real"__coeff_81'
#  'count__fft_coefficient__attr_"real"__coeff_82'
#  'count__fft_coefficient__attr_"real"__coeff_83'
#  'count__fft_coefficient__attr_"real"__coeff_84'
#  'count__fft_coefficient__attr_"real"__coeff_85'
#  'count__fft_coefficient__attr_"real"__coeff_86'
#  'count__fft_coefficient__attr_"real"__coeff_87'
#  'count__fft_coefficient__attr_"real"__coeff_88'
#  'count__fft_coefficient__attr_"real"__coeff_89'
#  'count__fft_coefficient__attr_"real"__coeff_90'
#  'count__fft_coefficient__attr_"real"__coeff_91'
#  'count__fft_coefficient__attr_"real"__coeff_92'
#  'count__fft_coefficient__attr_"real"__coeff_93'
#  'count__fft_coefficient__attr_"real"__coeff_94'
#  'count__fft_coefficient__attr_"real"__coeff_95'
#  'count__fft_coefficient__attr_"real"__coeff_96'
#  'count__fft_coefficient__attr_"real"__coeff_97'
#  'count__fft_coefficient__attr_"real"__coeff_98'
#  'count__fft_coefficient__attr_"real"__coeff_99'
#  'count__fft_coefficient__attr_"imag"__coeff_25'
#  'count__fft_coefficient__attr_"imag"__coeff_26'
#  'count__fft_coefficient__attr_"imag"__coeff_27'
#  'count__fft_coefficient__attr_"imag"__coeff_28'
#  'count__fft_coefficient__attr_"imag"__coeff_29'
#  'count__fft_coefficient__attr_"imag"__coeff_30'
#  'count__fft_coefficient__attr_"imag"__coeff_31'
#  'count__fft_coefficient__attr_"imag"__coeff_32'
#  'count__fft_coefficient__attr_"imag"__coeff_33'
#  'count__fft_coefficient__attr_"imag"__coeff_34'
#  'count__fft_coefficient__attr_"imag"__coeff_35'
#  'count__fft_coefficient__attr_"imag"__coeff_36'
#  'count__fft_coefficient__attr_"imag"__coeff_37'
#  'count__fft_coefficient__attr_"imag"__coeff_38'
#  'count__fft_coefficient__attr_"imag"__coeff_39'
#  'count__fft_coefficient__attr_"imag"__coeff_40'
#  'count__fft_coefficient__attr_"imag"__coeff_41'
#  'count__fft_coefficient__attr_"imag"__coeff_42'
#  'count__fft_coefficient__attr_"imag"__coeff_43'
#  'count__fft_coefficient__attr_"imag"__coeff_44'
#  'count__fft_coefficient__attr_"imag"__coeff_45'
#  'count__fft_coefficient__attr_"imag"__coeff_46'
#  'count__fft_coefficient__attr_"imag"__coeff_47'
#  'count__fft_coefficient__attr_"imag"__coeff_48'
#  'count__fft_coefficient__attr_"imag"__coeff_49'
#  'count__fft_coefficient__attr_"imag"__coeff_50'
#  'count__fft_coefficient__attr_"imag"__coeff_51'
#  'count__fft_coefficient__attr_"imag"__coeff_52'
#  'count__fft_coefficient__attr_"imag"__coeff_53'
#  'count__fft_coefficient__attr_"imag"__coeff_54'
#  'count__fft_coefficient__attr_"imag"__coeff_55'
#  'count__fft_coefficient__attr_"imag"__coeff_56'
#  'count__fft_coefficient__attr_"imag"__coeff_57'
#  'count__fft_coefficient__attr_"imag"__coeff_58'
#  'count__fft_coefficient__attr_"imag"__coeff_59'
#  'count__fft_coefficient__attr_"imag"__coeff_60'
#  'count__fft_coefficient__attr_"imag"__coeff_61'
#  'count__fft_coefficient__attr_"imag"__coeff_62'
#  'count__fft_coefficient__attr_"imag"__coeff_63'
#  'count__fft_coefficient__attr_"imag"__coeff_64'
#  'count__fft_coefficient__attr_"imag"__coeff_65'
#  'count__fft_coefficient__attr_"imag"__coeff_66'
#  'count__fft_coefficient__attr_"imag"__coeff_67'
#  'count__fft_coefficient__attr_"imag"__coeff_68'
#  'count__fft_coefficient__attr_"imag"__coeff_69'
#  'count__fft_coefficient__attr_"imag"__coeff_70'
#  'count__fft_coefficient__attr_"imag"__coeff_71'
#  'count__fft_coefficient__attr_"imag"__coeff_72'
#  'count__fft_coefficient__attr_"imag"__coeff_73'
#  'count__fft_coefficient__attr_"imag"__coeff_74'
#  'count__fft_coefficient__attr_"imag"__coeff_75'
#  'count__fft_coefficient__attr_"imag"__coeff_76'
#  'count__fft_coefficient__attr_"imag"__coeff_77'
#  'count__fft_coefficient__attr_"imag"__coeff_78'
#  'count__fft_coefficient__attr_"imag"__coeff_79'
#  'count__fft_coefficient__attr_"imag"__coeff_80'
#  'count__fft_coefficient__attr_"imag"__coeff_81'
#  'count__fft_coefficient__attr_"imag"__coeff_82'
#  'count__fft_coefficient__attr_"imag"__coeff_83'
#  'count__fft_coefficient__attr_"imag"__coeff_84'
#  'count__fft_coefficient__attr_"imag"__coeff_85'
#  'count__fft_coefficient__attr_"imag"__coeff_86'
#  'count__fft_coefficient__attr_"imag"__coeff_87'
#  'count__fft_coefficient__attr_"imag"__coeff_88'
#  'count__fft_coefficient__attr_"imag"__coeff_89'
#  'count__fft_coefficient__attr_"imag"__coeff_90'
#  'count__fft_coefficient__attr_"imag"__coeff_91'
#  'count__fft_coefficient__attr_"imag"__coeff_92'
#  'count__fft_coefficient__attr_"imag"__coeff_93'
#  'count__fft_coefficient__attr_"imag"__coeff_94'
#  'count__fft_coefficient__attr_"imag"__coeff_95'
#  'count__fft_coefficient__attr_"imag"__coeff_96'
#  'count__fft_coefficient__attr_"imag"__coeff_97'
#  'count__fft_coefficient__attr_"imag"__coeff_98'
#  'count__fft_coefficient__attr_"imag"__coeff_99'
#  'count__fft_coefficient__attr_"abs"__coeff_25'
#  'count__fft_coefficient__attr_"abs"__coeff_26'
#  'count__fft_coefficient__attr_"abs"__coeff_27'
#  'count__fft_coefficient__attr_"abs"__coeff_28'
#  'count__fft_coefficient__attr_"abs"__coeff_29'
#  'count__fft_coefficient__attr_"abs"__coeff_30'
#  'count__fft_coefficient__attr_"abs"__coeff_31'
#  'count__fft_coefficient__attr_"abs"__coeff_32'
#  'count__fft_coefficient__attr_"abs"__coeff_33'
#  'count__fft_coefficient__attr_"abs"__coeff_34'
#  'count__fft_coefficient__attr_"abs"__coeff_35'
#  'count__fft_coefficient__attr_"abs"__coeff_36'
#  'count__fft_coefficient__attr_"abs"__coeff_37'
#  'count__fft_coefficient__attr_"abs"__coeff_38'
#  'count__fft_coefficient__attr_"abs"__coeff_39'
#  'count__fft_coefficient__attr_"abs"__coeff_40'
#  'count__fft_coefficient__attr_"abs"__coeff_41'
#  'count__fft_coefficient__attr_"abs"__coeff_42'
#  'count__fft_coefficient__attr_"abs"__coeff_43'
#  'count__fft_coefficient__attr_"abs"__coeff_44'
#  'count__fft_coefficient__attr_"abs"__coeff_45'
#  'count__fft_coefficient__attr_"abs"__coeff_46'
#  'count__fft_coefficient__attr_"abs"__coeff_47'
#  'count__fft_coefficient__attr_"abs"__coeff_48'
#  'count__fft_coefficient__attr_"abs"__coeff_49'
#  'count__fft_coefficient__attr_"abs"__coeff_50'
#  'count__fft_coefficient__attr_"abs"__coeff_51'
#  'count__fft_coefficient__attr_"abs"__coeff_52'
#  'count__fft_coefficient__attr_"abs"__coeff_53'
#  'count__fft_coefficient__attr_"abs"__coeff_54'
#  'count__fft_coefficient__attr_"abs"__coeff_55'
#  'count__fft_coefficient__attr_"abs"__coeff_56'
#  'count__fft_coefficient__attr_"abs"__coeff_57'
#  'count__fft_coefficient__attr_"abs"__coeff_58'
#  'count__fft_coefficient__attr_"abs"__coeff_59'
#  'count__fft_coefficient__attr_"abs"__coeff_60'
#  'count__fft_coefficient__attr_"abs"__coeff_61'
#  'count__fft_coefficient__attr_"abs"__coeff_62'
#  'count__fft_coefficient__attr_"abs"__coeff_63'
#  'count__fft_coefficient__attr_"abs"__coeff_64'
#  'count__fft_coefficient__attr_"abs"__coeff_65'
#  'count__fft_coefficient__attr_"abs"__coeff_66'
#  'count__fft_coefficient__attr_"abs"__coeff_67'
#  'count__fft_coefficient__attr_"abs"__coeff_68'
#  'count__fft_coefficient__attr_"abs"__coeff_69'
#  'count__fft_coefficient__attr_"abs"__coeff_70'
#  'count__fft_coefficient__attr_"abs"__coeff_71'
#  'count__fft_coefficient__attr_"abs"__coeff_72'
#  'count__fft_coefficient__attr_"abs"__coeff_73'
#  'count__fft_coefficient__attr_"abs"__coeff_74'
#  'count__fft_coefficient__attr_"abs"__coeff_75'
#  'count__fft_coefficient__attr_"abs"__coeff_76'
#  'count__fft_coefficient__attr_"abs"__coeff_77'
#  'count__fft_coefficient__attr_"abs"__coeff_78'
#  'count__fft_coefficient__attr_"abs"__coeff_79'
#  'count__fft_coefficient__attr_"abs"__coeff_80'
#  'count__fft_coefficient__attr_"abs"__coeff_81'
#  'count__fft_coefficient__attr_"abs"__coeff_82'
#  'count__fft_coefficient__attr_"abs"__coeff_83'
#  'count__fft_coefficient__attr_"abs"__coeff_84'
#  'count__fft_coefficient__attr_"abs"__coeff_85'
#  'count__fft_coefficient__attr_"abs"__coeff_86'
#  'count__fft_coefficient__attr_"abs"__coeff_87'
#  'count__fft_coefficient__attr_"abs"__coeff_88'
#  'count__fft_coefficient__attr_"abs"__coeff_89'
#  'count__fft_coefficient__attr_"abs"__coeff_90'
#  'count__fft_coefficient__attr_"abs"__coeff_91'
#  'count__fft_coefficient__attr_"abs"__coeff_92'
#  'count__fft_coefficient__attr_"abs"__coeff_93'
#  'count__fft_coefficient__attr_"abs"__coeff_94'
#  'count__fft_coefficient__attr_"abs"__coeff_95'
#  'count__fft_coefficient__attr_"abs"__coeff_96'
#  'count__fft_coefficient__attr_"abs"__coeff_97'
#  'count__fft_coefficient__attr_"abs"__coeff_98'
#  'count__fft_coefficient__attr_"abs"__coeff_99'
#  'count__fft_coefficient__attr_"angle"__coeff_25'
#  'count__fft_coefficient__attr_"angle"__coeff_26'
#  'count__fft_coefficient__attr_"angle"__coeff_27'
#  'count__fft_coefficient__attr_"angle"__coeff_28'
#  'count__fft_coefficient__attr_"angle"__coeff_29'
#  'count__fft_coefficient__attr_"angle"__coeff_30'
#  'count__fft_coefficient__attr_"angle"__coeff_31'
#  'count__fft_coefficient__attr_"angle"__coeff_32'
#  'count__fft_coefficient__attr_"angle"__coeff_33'
#  'count__fft_coefficient__attr_"angle"__coeff_34'
#  'count__fft_coefficient__attr_"angle"__coeff_35'
#  'count__fft_coefficient__attr_"angle"__coeff_36'
#  'count__fft_coefficient__attr_"angle"__coeff_37'
#  'count__fft_coefficient__attr_"angle"__coeff_38'
#  'count__fft_coefficient__attr_"angle"__coeff_39'
#  'count__fft_coefficient__attr_"angle"__coeff_40'
#  'count__fft_coefficient__attr_"angle"__coeff_41'
#  'count__fft_coefficient__attr_"angle"__coeff_42'
#  'count__fft_coefficient__attr_"angle"__coeff_43'
#  'count__fft_coefficient__attr_"angle"__coeff_44'
#  'count__fft_coefficient__attr_"angle"__coeff_45'
#  'count__fft_coefficient__attr_"angle"__coeff_46'
#  'count__fft_coefficient__attr_"angle"__coeff_47'
#  'count__fft_coefficient__attr_"angle"__coeff_48'
#  'count__fft_coefficient__attr_"angle"__coeff_49'
#  'count__fft_coefficient__attr_"angle"__coeff_50'
#  'count__fft_coefficient__attr_"angle"__coeff_51'
#  'count__fft_coefficient__attr_"angle"__coeff_52'
#  'count__fft_coefficient__attr_"angle"__coeff_53'
#  'count__fft_coefficient__attr_"angle"__coeff_54'
#  'count__fft_coefficient__attr_"angle"__coeff_55'
#  'count__fft_coefficient__attr_"angle"__coeff_56'
#  'count__fft_coefficient__attr_"angle"__coeff_57'
#  'count__fft_coefficient__attr_"angle"__coeff_58'
#  'count__fft_coefficient__attr_"angle"__coeff_59'
#  'count__fft_coefficient__attr_"angle"__coeff_60'
#  'count__fft_coefficient__attr_"angle"__coeff_61'
#  'count__fft_coefficient__attr_"angle"__coeff_62'
#  'count__fft_coefficient__attr_"angle"__coeff_63'
#  'count__fft_coefficient__attr_"angle"__coeff_64'
#  'count__fft_coefficient__attr_"angle"__coeff_65'
#  'count__fft_coefficient__attr_"angle"__coeff_66'
#  'count__fft_coefficient__attr_"angle"__coeff_67'
#  'count__fft_coefficient__attr_"angle"__coeff_68'
#  'count__fft_coefficient__attr_"angle"__coeff_69'
#  'count__fft_coefficient__attr_"angle"__coeff_70'
#  'count__fft_coefficient__attr_"angle"__coeff_71'
#  'count__fft_coefficient__attr_"angle"__coeff_72'
#  'count__fft_coefficient__attr_"angle"__coeff_73'
#  'count__fft_coefficient__attr_"angle"__coeff_74'
#  'count__fft_coefficient__attr_"angle"__coeff_75'
#  'count__fft_coefficient__attr_"angle"__coeff_76'
#  'count__fft_coefficient__attr_"angle"__coeff_77'
#  'count__fft_coefficient__attr_"angle"__coeff_78'
#  'count__fft_coefficient__attr_"angle"__coeff_79'
#  'count__fft_coefficient__attr_"angle"__coeff_80'
#  'count__fft_coefficient__attr_"angle"__coeff_81'
#  'count__fft_coefficient__attr_"angle"__coeff_82'
#  'count__fft_coefficient__attr_"angle"__coeff_83'
#  'count__fft_coefficient__attr_"angle"__coeff_84'
#  'count__fft_coefficient__attr_"angle"__coeff_85'
#  'count__fft_coefficient__attr_"angle"__coeff_86'
#  'count__fft_coefficient__attr_"angle"__coeff_87'
#  'count__fft_coefficient__attr_"angle"__coeff_88'
#  'count__fft_coefficient__attr_"angle"__coeff_89'
#  'count__fft_coefficient__attr_"angle"__coeff_90'
#  'count__fft_coefficient__attr_"angle"__coeff_91'
#  'count__fft_coefficient__attr_"angle"__coeff_92'
#  'count__fft_coefficient__attr_"angle"__coeff_93'
#  'count__fft_coefficient__attr_"angle"__coeff_94'
#  'count__fft_coefficient__attr_"angle"__coeff_95'
#  'count__fft_coefficient__attr_"angle"__coeff_96'
#  'count__fft_coefficient__attr_"angle"__coeff_97'
#  'count__fft_coefficient__attr_"angle"__coeff_98'
#  'count__fft_coefficient__attr_"angle"__coeff_99'
#  'count__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"max"'
#  'count__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"min"'
#  'count__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"mean"'
#  'count__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"var"'
#  'count__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"'
#  'count__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"min"'
#  'count__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"mean"'
#  'count__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"var"'
#  'count__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"max"'
#  'count__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"min"'
#  'count__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"mean"'
#  'count__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"var"'
#  'count__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"max"'
#  'count__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"min"'
#  'count__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"mean"'
#  'count__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"var"'
#  'count__query_similarity_count__query_None__threshold_0.0'] did not have any finite values. Filling with zeros.
#   warnings.warn(
#                 count__variance_larger_than_standard_deviation  \
# CVE
# CVE-2006-10001                                             1.0
# CVE-2008-10002                                             0.0
# CVE-2008-10003                                             1.0
# CVE-2008-10004                                             1.0
# CVE-2011-10002                                             1.0
# ...                                                        ...
# CVE-2023-28685                                             0.0
# CVE-2023-28686                                             1.0
# CVE-2023-28708                                             1.0
# CVE-2023-28725                                             1.0
# CVE-2023-28818                                             1.0
#
#                 count__has_duplicate_max  count__has_duplicate_min  \
# CVE
# CVE-2006-10001                       0.0                       1.0
# CVE-2008-10002                       1.0                       1.0
# CVE-2008-10003                       0.0                       1.0
# CVE-2008-10004                       0.0                       1.0
# CVE-2011-10002                       0.0                       1.0
# ...                                  ...                       ...
# CVE-2023-28685                       0.0                       1.0
# CVE-2023-28686                       1.0                       1.0
# CVE-2023-28708                       0.0                       1.0
# CVE-2023-28725                       0.0                       0.0
# CVE-2023-28818                       1.0                       0.0
#
#                 count__has_duplicate  count__sum_values  count__abs_energy  \
# CVE
# CVE-2006-10001                   1.0               16.0               60.0
# CVE-2008-10002                   1.0               15.0               37.0
# CVE-2008-10003                   1.0               16.0               44.0
# CVE-2008-10004                   1.0               20.0              110.0
# CVE-2011-10002                   1.0               12.0               54.0
# ...                              ...                ...                ...
# CVE-2023-28685                   1.0               15.0               35.0
# CVE-2023-28686                   1.0               15.0               43.0
# CVE-2023-28708                   1.0               30.0              100.0
# CVE-2023-28725                   1.0               15.0               61.0
# CVE-2023-28818                   1.0               13.0               41.0
#
#                 count__mean_abs_change  count__mean_change  \
# CVE
# CVE-2006-10001                2.000000           -0.400000
# CVE-2008-10002                1.333333           -0.333333
# CVE-2008-10003                1.000000           -0.333333
# CVE-2008-10004                4.000000           -0.333333
# CVE-2011-10002                2.333333           -1.000000
# ...                                ...                 ...
# CVE-2023-28685                1.285714           -0.142857
# CVE-2023-28686                1.666667            0.000000
# CVE-2023-28708                1.692308           -0.153846
# CVE-2023-28725                2.250000           -0.250000
# CVE-2023-28818                2.250000           -0.250000
#
#                 count__mean_second_derivative_central  count__median  ...  \
# CVE                                                                   ...
# CVE-2006-10001                               0.125000            2.5  ...
# CVE-2008-10002                               0.100000            2.0  ...
# CVE-2008-10003                              -0.100000            2.0  ...
# CVE-2008-10004                               0.200000            1.0  ...
# CVE-2011-10002                              -0.500000            2.5  ...
# ...                                               ...            ...  ...
# CVE-2023-28685                               0.000000            2.0  ...
# CVE-2023-28686                              -0.100000            2.0  ...
# CVE-2023-28708                              -0.125000            1.0  ...
# CVE-2023-28725                              -0.500000            2.0  ...
# CVE-2023-28818                              -0.833333            2.0  ...
#
#                 count__fourier_entropy__bins_5  \
# CVE
# CVE-2006-10001                        1.039721
# CVE-2008-10002                        1.039721
# CVE-2008-10003                        1.386294
# CVE-2008-10004                        1.039721
# CVE-2011-10002                        1.098612
# ...                                        ...
# CVE-2023-28685                        1.332179
# CVE-2023-28686                        1.039721
# CVE-2023-28708                        1.494175
# CVE-2023-28725                        1.098612
# CVE-2023-28818                        0.636514
#
#                 count__fourier_entropy__bins_10  \
# CVE
# CVE-2006-10001                         1.039721
# CVE-2008-10002                         1.039721
# CVE-2008-10003                         1.386294
# CVE-2008-10004                         1.386294
# CVE-2011-10002                         1.098612
# ...                                         ...
# CVE-2023-28685                         1.332179
# CVE-2023-28686                         1.039721
# CVE-2023-28708                         1.732868
# CVE-2023-28725                         1.098612
# CVE-2023-28818                         0.636514
#
#                 count__fourier_entropy__bins_100  \
# CVE
# CVE-2006-10001                          1.386294
# CVE-2008-10002                          1.039721
# CVE-2008-10003                          1.386294
# CVE-2008-10004                          1.386294
# CVE-2011-10002                          1.098612
# ...                                          ...
# CVE-2023-28685                          1.609438
# CVE-2023-28686                          1.386294
# CVE-2023-28708                          1.906155
# CVE-2023-28725                          1.098612
# CVE-2023-28818                          1.098612
#
#                 count__permutation_entropy__dimension_3__tau_1  \
# CVE
# CVE-2006-10001                                        1.386294
# CVE-2008-10002                                        1.054920
# CVE-2008-10003                                        1.332179
# CVE-2008-10004                                        1.054920
# CVE-2011-10002                                        0.693147
# ...                                                        ...
# CVE-2023-28685                                        1.329661
# CVE-2023-28686                                        1.609438
# CVE-2023-28708                                        1.329661
# CVE-2023-28725                                        1.098612
# CVE-2023-28818                                        1.098612
#
#                 count__permutation_entropy__dimension_4__tau_1  \
# CVE
# CVE-2006-10001                                        1.098612
# CVE-2008-10002                                        1.039721
# CVE-2008-10003                                        1.386294
# CVE-2008-10004                                        1.039721
# CVE-2011-10002                                       -0.000000
# ...                                                        ...
# CVE-2023-28685                                        1.609438
# CVE-2023-28686                                        1.386294
# CVE-2023-28708                                        1.893788
# CVE-2023-28725                                        0.693147
# CVE-2023-28818                                        0.693147
#
#                 count__permutation_entropy__dimension_5__tau_1  \
# CVE
# CVE-2006-10001                                        0.693147
# CVE-2008-10002                                        1.098612
# CVE-2008-10003                                        1.098612
# CVE-2008-10004                                        1.098612
# CVE-2011-10002                                        0.693147
# ...                                                        ...
# CVE-2023-28685                                        1.386294
# CVE-2023-28686                                        1.098612
# CVE-2023-28708                                        2.302585
# CVE-2023-28725                                       -0.000000
# CVE-2023-28818                                       -0.000000
#
#                 count__permutation_entropy__dimension_6__tau_1  \
# CVE
# CVE-2006-10001                                       -0.000000
# CVE-2008-10002                                        0.693147
# CVE-2008-10003                                        0.693147
# CVE-2008-10004                                        0.693147
# CVE-2011-10002                                        0.693147
# ...                                                        ...
# CVE-2023-28685                                        1.098612
# CVE-2023-28686                                        0.693147
# CVE-2023-28708                                        2.197225
# CVE-2023-28725                                        0.693147
# CVE-2023-28818                                        0.693147
#
#                 count__permutation_entropy__dimension_7__tau_1  \
# CVE
# CVE-2006-10001                                        0.693147
# CVE-2008-10002                                       -0.000000
# CVE-2008-10003                                       -0.000000
# CVE-2008-10004                                       -0.000000
# CVE-2011-10002                                        0.693147
# ...                                                        ...
# CVE-2023-28685                                        0.693147
# CVE-2023-28686                                       -0.000000
# CVE-2023-28708                                        2.079442
# CVE-2023-28725                                        0.693147
# CVE-2023-28818                                        0.693147
#
#                 count__query_similarity_count__query_None__threshold_0.0  \
# CVE
# CVE-2006-10001                                                0.0
# CVE-2008-10002                                                0.0
# CVE-2008-10003                                                0.0
# CVE-2008-10004                                                0.0
# CVE-2011-10002                                                0.0
# ...                                                           ...
# CVE-2023-28685                                                0.0
# CVE-2023-28686                                                0.0
# CVE-2023-28708                                                0.0
# CVE-2023-28725                                                0.0
# CVE-2023-28818                                                0.0
#
#                 count__mean_n_absolute_max__number_of_maxima_7
# CVE
# CVE-2006-10001                                        2.285714
# CVE-2008-10002                                        2.285714
# CVE-2008-10003                                        2.285714
# CVE-2008-10004                                        2.285714
# CVE-2011-10002                                        2.285714
# ...                                                        ...
# CVE-2023-28685                                        2.000000
# CVE-2023-28686                                        2.285714
# CVE-2023-28708                                        3.285714
# CVE-2023-28725                                        2.285714
# CVE-2023-28818                                        2.285714
#
# [1677 rows x 783 columns]

# %% [markdown]
# ## Train-test split

# %%
train_data = df_features
y = df_flag_sorted['flag_H']
X = train_data.values

# stratify　= y: 訓練データとテストデータの陽性陰性の比率が同一になるように分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, shuffle = True, stratify = y, random_state = 1234)

# %% [markdown]
# ## Model

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %% [markdown]
# ## Scores

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.32      0.48      0.39       126
#            1       0.79      0.66      0.72       378
#
#     accuracy                           0.62       504
#    macro avg       0.56      0.57      0.55       504
# weighted avg       0.68      0.62      0.64       504

# %%
print("Accuracy:{:.3f}".format(accuracy_score(y_test, y_pred)))
print("Precision:{:.3f}".format(precision_score(y_test, y_pred)))
print("Recall:{:.3f}".format(recall_score(y_test, y_pred)))
print("F1 Score:{:.3f}".format(f1_score(y_test, y_pred)))
# Out:
# Accuracy:0.617
# Precision:0.661
# Recall:0.794
# F1 Score:0.722

# %% [markdown]
# # Hyper Parameter tuning

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Define the stratified_kfold_score function for bayesian OP
def stratified_kfold_score(clf,X,y,n_fold):
    #X,y = X,y
    strat_kfold = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=1234)
    f1score_list = []

    for train_index, test_index in strat_kfold.split(X, y):
        x_train_fold, x_test_fold = X[train_index], X[test_index]
        y_train_fold, y_test_fold = y[train_index], y[test_index]
        clf.fit(x_train_fold, y_train_fold)
        y_pred = clf.predict(x_test_fold)
        f1score_test = f1_score(y_pred,y_test_fold)
        f1score_list.append(f1score_test)

    return np.array(f1score_list).mean()

# %%
# Define the function to maximize
def bo_params_rf(max_samples,n_estimators,max_features):
    
    params = {
        'max_samples': max_samples,
        'max_features':max_features,
        'n_estimators':int(n_estimators)
    }
    clf = RandomForestClassifier(max_samples=params['max_samples'],max_features=params['max_features'],n_estimators=params['n_estimators'])
    score = stratified_kfold_score(clf,X_train, y_train, 10)
    return score

# %%
rf_bo = BayesianOptimization(f=bo_params_rf, pbounds={
                                              "max_samples": (0.0, 1.0),
                                                'max_features':(0.5,1),
                                              'n_estimators':(200,2000)
                                             },random_state=1234, verbose=2)

# %%
results = rf_bo.maximize(n_iter=200, init_points=20)
# Out:
# |   iter    |  target   | max_fe... | max_sa... | n_esti... |
# -------------------------------------------------------------
# | 1         | 0.748     | 0.5958    | 0.6221    | 987.9     |
# | 2         | 0.7464    | 0.8927    | 0.78      | 690.7     |
# | 3         | 0.7456    | 0.6382    | 0.8019    | 1.925e+03 |
# | 4         | 0.7548    | 0.938     | 0.3578    | 1.102e+03 |
# | 5         | 0.75      | 0.8417    | 0.7127    | 866.5     |
# | 6         | 0.7527    | 0.7806    | 0.5031    | 224.8     |
# | 7         | 0.7483    | 0.8864    | 0.8826    | 856.8     |
# | 8         | 0.7715    | 0.8077    | 0.07538   | 863.9     |
# | 9         | 0.7488    | 0.9666    | 0.6514    | 915.0     |
# | 10        | 0.7524    | 0.8944    | 0.3168    | 1.223e+03 |
# | 11        | 0.75      | 0.9346    | 0.4362    | 1.644e+03 |
# | 12        | 0.7468    | 0.5719    | 0.7043    | 1.468e+03 |
# | 13        | 0.7529    | 0.6094    | 0.9249    | 995.9     |
# | 14        | 0.7663    | 0.9547    | 0.05981   | 531.7     |
# | 15        | 0.7492    | 0.5237    | 0.6749    | 1.27e+03  |
# | 16        | 0.7678    | 0.7667    | 0.04332   | 1.211e+03 |
# | 17        | 0.7494    | 0.6648    | 0.503     | 401.4     |
# | 18        | 0.7489    | 0.8036    | 0.5659    | 212.2     |
# | 19        | 0.7433    | 0.8087    | 0.9121    | 1.623e+03 |
# | 20        | 0.7442    | 0.996     | 0.9588    | 1.626e+03 |
# | 21        | 0.7461    | 0.6459    | 0.7119    | 863.5     |
# | 22        | 0.745     | 0.9584    | 0.6169    | 725.8     |
# | 23        | 0.7467    | 0.9441    | 0.9369    | 676.4     |
# | 24        | 0.7658    | 0.6341    | 0.08837   | 519.7     |
# | 25        | 0.7474    | 0.5841    | 0.4017    | 373.2     |
# | 26        | 0.7691    | 0.7412    | 0.01272   | 855.0     |
# | 27        | 0.7681    | 0.8712    | 0.165     | 1.618e+03 |
# | 28        | 0.7499    | 0.5241    | 0.6821    | 1.937e+03 |
# | 29        | 0.7638    | 0.8128    | 0.2292    | 1.407e+03 |
# | 30        | 0.7482    | 0.7159    | 0.5789    | 1.371e+03 |
# | 31        | 0.7431    | 0.7698    | 0.8594    | 1.166e+03 |
# | 32        | 0.7497    | 0.6558    | 0.6278    | 992.4     |
# | 33        | 0.749     | 0.7812    | 0.8469    | 1.004e+03 |
# | 34        | 0.7559    | 0.8985    | 0.3099    | 1.272e+03 |
# | 35        | 0.7561    | 0.739     | 0.6261    | 707.4     |
# | 36        | 0.748     | 0.9492    | 0.993     | 1.386e+03 |
# | 37        | 0.7601    | 0.6269    | 0.08545   | 291.6     |
# | 38        | 0.7451    | 0.8357    | 0.813     | 1.816e+03 |
# | 39        | 0.7526    | 0.9767    | 0.4587    | 1.272e+03 |
# | 40        | 0.7504    | 0.6583    | 0.9593    | 1.116e+03 |
# | 41        | 0.7453    | 0.7303    | 0.4003    | 221.4     |
# | 42        | 0.7761    | 0.6704    | 0.07503   | 239.9     |
# | 43        | 0.7572    | 0.5641    | 0.3678    | 301.5     |
# | 44        | 0.7627    | 0.5877    | 0.263     | 1.528e+03 |
# | 45        | 0.7657    | 0.6652    | 0.1104    | 289.6     |
# | 46        | 0.756     | 0.872     | 0.3355    | 1.017e+03 |
# | 47        | 0.7704    | 0.5483    | 0.1649    | 1.704e+03 |
# | 48        | 0.7475    | 0.6773    | 0.8064    | 496.4     |
# | 49        | 0.748     | 0.7725    | 0.5074    | 892.3     |
# | 50        | 0.7659    | 0.544     | 0.03303   | 742.8     |
# | 51        | 0.7435    | 0.6409    | 0.7723    | 894.7     |
# | 52        | 0.7588    | 0.7845    | 0.3711    | 1.993e+03 |
# | 53        | 0.7676    | 0.9461    | 0.1783    | 820.9     |
# | 54        | 0.7413    | 0.5671    | 0.9483    | 485.5     |
# | 55        | 0.7517    | 0.6226    | 0.4263    | 1.198e+03 |
# | 56        | 0.7533    | 0.6448    | 0.5657    | 1.204e+03 |
# | 57        | 0.7509    | 0.6       | 0.7279    | 1.425e+03 |
# | 58        | 0.7492    | 0.7675    | 0.6023    | 1.046e+03 |
# | 59        | 0.7472    | 0.9551    | 0.7297    | 749.7     |
# | 60        | 0.7462    | 0.8661    | 0.7917    | 916.3     |
# | 61        | 0.7522    | 0.5117    | 0.4634    | 340.4     |
# | 62        | 0.7475    | 0.7539    | 0.7009    | 1.153e+03 |
# | 63        | 0.7458    | 0.7105    | 0.956     | 685.0     |
# | 64        | 0.7634    | 0.7783    | 0.2581    | 957.2     |
# | 65        | 0.7609    | 0.6487    | 0.2675    | 1.888e+03 |
# | 66        | 0.769     | 0.9457    | 0.06418   | 1.317e+03 |
# | 67        | 0.7461    | 0.6101    | 0.9046    | 511.4     |
# | 68        | 0.7699    | 0.9382    | 0.01718   | 1.817e+03 |
# | 69        | 0.7466    | 0.8125    | 0.574     | 960.1     |
# | 70        | 0.7495    | 0.9113    | 0.6602    | 698.6     |
# | 71        | 0.7408    | 0.8672    | 0.7735    | 498.1     |
# | 72        | 0.7677    | 0.7424    | 0.1498    | 633.3     |
# | 73        | 0.7629    | 0.5098    | 0.2132    | 604.9     |
# | 74        | 0.7384    | 0.9052    | 0.5225    | 284.1     |
# | 75        | 0.746     | 0.6426    | 0.6648    | 1.565e+03 |
# | 76        | 0.7497    | 0.8296    | 0.5034    | 1.062e+03 |
# | 77        | 0.7482    | 0.6552    | 0.6282    | 1.058e+03 |
# | 78        | 0.7444    | 0.6042    | 0.7965    | 903.5     |
# | 79        | 0.7507    | 0.5563    | 0.7301    | 800.8     |
# | 80        | 0.7465    | 0.5581    | 0.6614    | 986.7     |
# | 81        | 0.7627    | 0.8487    | 0.07661   | 347.4     |
# | 82        | 0.7431    | 0.8358    | 0.5644    | 693.9     |
# | 83        | 0.7433    | 0.7637    | 0.6793    | 472.0     |
# | 84        | 0.745     | 0.814     | 0.9878    | 1.105e+03 |
# | 85        | 0.7541    | 0.6635    | 0.431     | 1.987e+03 |
# | 86        | 0.7454    | 0.833     | 0.5322    | 1.192e+03 |
# | 87        | 0.7508    | 0.7427    | 0.49      | 1.626e+03 |
# | 88        | 0.7666    | 0.5457    | 0.1668    | 240.0     |
# | 89        | 0.7675    | 0.8173    | 0.172     | 863.8     |
# | 90        | 0.7633    | 0.7174    | 0.103     | 239.6     |
# | 91        | 0.7645    | 0.5649    | 0.1895    | 240.0     |
# | 92        | 0.7691    | 0.5772    | 0.01096   | 1.704e+03 |
# | 93        | 0.7553    | 0.9657    | 0.3146    | 1.317e+03 |
# | 94        | 0.7657    | 0.635     | 0.01838   | 240.0     |
# | 95        | 0.774     | 0.6644    | 0.1148    | 1.704e+03 |
# | 96        | 0.7581    | 0.8003    | 0.3131    | 1.705e+03 |
# | 97        | 0.7663    | 0.6616    | 0.1617    | 1.704e+03 |
# | 98        | 0.7675    | 0.7728    | 0.1168    | 1.052e+03 |
# | 99        | 0.7621    | 0.5947    | 0.04976   | 234.1     |
# | 100       | 0.7613    | 0.6614    | 0.2843    | 864.0     |
# | 101       | 0.7709    | 0.8148    | 0.2034    | 1.407e+03 |
# | 102       | 0.7697    | 0.7451    | 0.08762   | 239.8     |
# | 103       | 0.7683    | 0.7552    | 0.05674   | 1.407e+03 |
# | 104       | 0.7691    | 0.8354    | 0.09918   | 1.407e+03 |
# | 105       | 0.7729    | 0.8196    | 0.1029    | 1.817e+03 |
# | 106       | 0.7396    | 0.5472    | 0.9037    | 1.863e+03 |
# | 107       | 0.7646    | 0.955     | 0.2291    | 1.407e+03 |
# | 108       | 0.7672    | 0.987     | 0.1397    | 1.312e+03 |
# | 109       | 0.7608    | 0.8932    | 0.2983    | 633.2     |
# | 110       | 0.7665    | 0.8669    | 0.1662    | 1.818e+03 |
# | 111       | 0.7514    | 0.7724    | 0.4688    | 254.8     |
# | 112       | 0.7585    | 0.5708    | 0.2905    | 1.407e+03 |
# | 113       | 0.7715    | 0.808     | 0.07012   | 1.407e+03 |
# | 114       | 0.749     | 0.7664    | 0.9636    | 1.075e+03 |
# | 115       | 0.7664    | 0.9441    | 0.1006    | 1.817e+03 |
# | 116       | 0.7603    | 0.8669    | 0.2303    | 1.68e+03  |
# | 117       | 0.7659    | 0.8366    | 0.03733   | 1.704e+03 |
# | 118       | 0.7472    | 0.5098    | 0.9106    | 1.071e+03 |
# | 119       | 0.7633    | 0.7091    | 0.1997    | 1.407e+03 |
# | 120       | 0.7626    | 0.6483    | 0.2284    | 1.704e+03 |
# | 121       | 0.7601    | 0.9235    | 0.2871    | 1.221e+03 |
# | 122       | 0.7654    | 0.7555    | 0.1809    | 1.817e+03 |
# | 123       | 0.7505    | 0.5598    | 0.4466    | 651.3     |
# | 124       | 0.7706    | 0.5865    | 0.1669    | 1.705e+03 |
# | 125       | 0.7678    | 0.8646    | 0.1015    | 1.407e+03 |
# | 126       | 0.7464    | 0.9983    | 0.7057    | 888.8     |
# | 127       | 0.7666    | 0.54      | 0.0386    | 1.704e+03 |
# | 128       | 0.7491    | 0.5503    | 0.5919    | 1.527e+03 |
# | 129       | 0.7737    | 0.764     | 0.07291   | 1.317e+03 |
# | 130       | 0.7484    | 0.8354    | 0.5534    | 1.479e+03 |
# | 131       | 0.7675    | 0.827     | 0.125     | 579.9     |
# | 132       | 0.7504    | 0.6085    | 0.5172    | 1.59e+03  |
# | 133       | 0.7661    | 0.6865    | 0.1775    | 1.317e+03 |
# | 134       | 0.7415    | 0.9038    | 0.9756    | 223.9     |
# | 135       | 0.7489    | 0.7168    | 0.7399    | 1.877e+03 |
# | 136       | 0.7671    | 0.6162    | 0.1991    | 1.052e+03 |
# | 137       | 0.7643    | 0.5673    | 0.03345   | 1.317e+03 |
# | 138       | 0.764     | 0.8401    | 0.2571    | 1.115e+03 |
# | 139       | 0.744     | 0.885     | 0.8402    | 469.9     |
# | 140       | 0.7739    | 0.6122    | 0.05464   | 239.8     |
# | 141       | 0.7658    | 0.5047    | 0.02837   | 1.635e+03 |
# | 142       | 0.7415    | 0.6235    | 0.8488    | 486.7     |
# | 143       | 0.7708    | 0.6146    | 0.05385   | 855.2     |
# | 144       | 0.769     | 0.928     | 0.1706    | 1.458e+03 |
# | 145       | 0.7673    | 0.6601    | 0.06875   | 855.4     |
# | 146       | 0.7678    | 0.8041    | 0.02293   | 855.2     |
# | 147       | 0.7648    | 0.6783    | 0.1753    | 1.817e+03 |
# | 148       | 0.7614    | 0.8691    | 0.2872    | 1.817e+03 |
# | 149       | 0.7667    | 0.8715    | 0.1449    | 864.0     |
# | 150       | 0.7521    | 0.8523    | 0.317     | 1.052e+03 |
# | 151       | 0.7679    | 0.7343    | 0.1965    | 1.407e+03 |
# | 152       | 0.7619    | 0.765     | 0.275     | 855.0     |
# | 153       | 0.7697    | 0.9384    | 0.1742    | 1.458e+03 |
# | 154       | 0.7691    | 0.8543    | 0.0121    | 1.458e+03 |
# | 155       | 0.7509    | 0.5656    | 0.4335    | 539.5     |
# | 156       | 0.7689    | 0.7382    | 0.01339   | 864.0     |
# | 157       | 0.7487    | 0.8118    | 0.4137    | 928.2     |
# | 158       | 0.7677    | 0.5495    | 0.09957   | 566.0     |
# | 159       | 0.774     | 0.7414    | 0.07001   | 1.458e+03 |
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 results = rf_bo.maximize(n_iter=200, init_points=20)
#
# File ~/.local/lib/python3.10/site-packages/bayes_opt/bayesian_optimization.py:311, in BayesianOptimization.maximize(self, init_points, n_iter, acquisition_function, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     309     x_probe = self.suggest(util)
#     310     iteration += 1
# --> 311 self.probe(x_probe, lazy=False)
#     313 if self._bounds_transformer and iteration > 0:
#     314     # The bounds transformer should only modify the bounds after
#     315     # the init_points points (only for the true iterations)
#     316     self.set_bounds(
#     317         self._bounds_transformer.transform(self._space))
#
# File ~/.local/lib/python3.10/site-packages/bayes_opt/bayesian_optimization.py:208, in BayesianOptimization.probe(self, params, lazy)
#     206     self._queue.add(params)
#     207 else:
# --> 208     self._space.probe(params)
#     209     self.dispatch(Events.OPTIMIZATION_STEP)
#
# File ~/.local/lib/python3.10/site-packages/bayes_opt/target_space.py:236, in TargetSpace.probe(self, params)
#     234 x = self._as_array(params)
#     235 params = dict(zip(self._keys, x))
# --> 236 target = self.target_func(**params)
#     238 if self._constraint is None:
#     239     self.register(x, target)
#
# Cell In[17], line 10, in bo_params_rf(max_samples, n_estimators, max_features)
#       4 params = {
#       5     'max_samples': max_samples,
#       6     'max_features':max_features,
#       7     'n_estimators':int(n_estimators)
#       8 }
#       9 clf = RandomForestClassifier(max_samples=params['max_samples'],max_features=params['max_features'],n_estimators=params['n_estimators'])
# ---> 10 score = stratified_kfold_score(clf,X_train, y_train, 10)
#      11 return score
#
# Cell In[16], line 10, in stratified_kfold_score(clf, X, y, n_fold)
#       8 x_train_fold, x_test_fold = X[train_index], X[test_index]
#       9 y_train_fold, y_test_fold = y[train_index], y[test_index]
# ---> 10 clf.fit(x_train_fold, y_train_fold)
#      11 y_pred = clf.predict(x_test_fold)
#      12 f1score_test = f1_score(y_pred,y_test_fold)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:340, in BaseForest.fit(self, X, y, sample_weight)
#     313 def fit(self, X, y, sample_weight=None):
#     314     """
#     315     Build a forest of trees from the training set (X, y).
#     316
#    (...)
#     338         Fitted estimator.
#     339     """
# --> 340     self._validate_params()
#     342     # Validate or convert input data
#     343     if issparse(y):
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:600, in BaseEstimator._validate_params(self)
#     592 def _validate_params(self):
#     593     """Validate types and values of constructor parameters
#     594
#     595     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     598     accepted constraints.
#     599     """
# --> 600     validate_parameter_constraints(
#     601         self._parameter_constraints,
#     602         self.get_params(deep=False),
#     603         caller_name=self.__class__.__name__,
#     604     )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:97, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      91 else:
#      92     constraints_str = (
#      93         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      94         f" {constraints[-1]}"
#      95     )
# ---> 97 raise InvalidParameterError(
#      98     f"The {param_name!r} parameter of {caller_name} must be"
#      99     f" {constraints_str}. Got {param_val!r} instead."
#     100 )
#
# InvalidParameterError: The 'max_samples' parameter of RandomForestClassifier must be None, a float in the range (0.0, 1.0] or an int in the range [1, inf). Got 0.0 instead.

# %%
results = rf_bo.maximize(n_iter=200, init_points=20)
# Out:
# |   iter    |  target   | max_fe... | max_sa... | n_esti... |
# -------------------------------------------------------------
# | 160       | 0.748     | 0.6426    | 0.6249    | 1.061e+03 |
# | 161       | 0.7541    | 0.5978    | 0.3823    | 297.0     |
# | 162       | 0.7465    | 0.7258    | 0.982     | 423.1     |
# | 163       | 0.7489    | 0.5597    | 0.7385    | 1.257e+03 |
# | 164       | 0.7669    | 0.7358    | 0.1071    | 612.6     |
# | 165       | 0.7508    | 0.95      | 0.4168    | 1.165e+03 |
# | 166       | 0.7617    | 0.5031    | 0.3006    | 986.4     |
# | 167       | 0.7448    | 0.8061    | 0.9182    | 1.326e+03 |
# | 168       | 0.7675    | 0.853     | 0.1498    | 1.543e+03 |
# | 169       | 0.7439    | 0.9155    | 0.6337    | 989.0     |
# | 170       | 0.7496    | 0.5763    | 0.5684    | 1.151e+03 |
# | 171       | 0.7559    | 0.9757    | 0.4804    | 1.105e+03 |
# | 172       | 0.7448    | 0.7684    | 0.8192    | 302.8     |
# | 173       | 0.7414    | 0.8347    | 0.7671    | 1.475e+03 |
# | 174       | 0.753     | 0.8984    | 0.5578    | 1.939e+03 |
# | 175       | 0.7709    | 0.5736    | 0.02965   | 1.269e+03 |
# | 176       | 0.7403    | 0.557     | 0.9508    | 786.3     |
# | 177       | 0.7523    | 0.5968    | 0.4578    | 1.857e+03 |
# | 178       | 0.7655    | 0.9395    | 0.2526    | 826.4     |
# | 179       | 0.7435    | 0.5913    | 0.9018    | 1.472e+03 |
# | 180       | 0.7556    | 0.8267    | 0.5357    | 903.4     |
# | 181       | 0.7705    | 0.7366    | 0.01573   | 1.457e+03 |
# | 182       | 0.7667    | 0.7521    | 0.04361   | 1.458e+03 |
# | 183       | 0.7718    | 0.5463    | 0.08992   | 1.458e+03 |
# | 184       | 0.7587    | 0.5055    | 0.2559    | 661.7     |
# | 185       | 0.7692    | 0.7945    | 0.03445   | 1.317e+03 |
# | 186       | 0.7683    | 0.7289    | 0.1938    | 1.458e+03 |
# | 187       | 0.7705    | 0.8855    | 0.121     | 415.1     |
# | 188       | 0.7698    | 0.689     | 0.1794    | 1.317e+03 |
# | 189       | 0.7722    | 0.5524    | 0.06802   | 1.458e+03 |
# | 190       | 0.773     | 0.8063    | 0.04896   | 1.705e+03 |
# | 191       | 0.7502    | 0.6369    | 0.9705    | 1.716e+03 |
# | 192       | 0.7614    | 0.9955    | 0.2643    | 1.407e+03 |
# | 193       | 0.7521    | 0.8722    | 0.2603    | 255.7     |
# | 194       | 0.7681    | 0.7739    | 0.1673    | 633.3     |
# | 195       | 0.7667    | 0.9389    | 0.2157    | 415.4     |
# | 196       | 0.77      | 0.7748    | 0.1934    | 1.705e+03 |
# | 197       | 0.7691    | 0.6447    | 0.006616  | 1.705e+03 |
# | 198       | 0.7732    | 0.5782    | 0.1759    | 1.269e+03 |
# | 199       | 0.7706    | 0.6369    | 0.06558   | 1.269e+03 |
# | 200       | 0.7741    | 0.834     | 0.1053    | 1.269e+03 |
# | 201       | 0.7672    | 0.9077    | 0.109     | 1.269e+03 |
# | 202       | 0.7533    | 0.7959    | 0.357     | 1.269e+03 |
# | 203       | 0.7595    | 0.7002    | 0.2881    | 1.709e+03 |
# | 204       | 0.766     | 0.5955    | 0.1931    | 1.269e+03 |
# | 205       | 0.7679    | 0.559     | 0.03257   | 454.9     |
# | 206       | 0.7677    | 0.947     | 0.1671    | 1.705e+03 |
# | 207       | 0.7437    | 0.9083    | 0.7526    | 1.151e+03 |
# | 208       | 0.7474    | 0.9316    | 0.9308    | 641.8     |
# | 209       | 0.7698    | 0.9348    | 0.1185    | 1.269e+03 |
# | 210       | 0.7446    | 0.6636    | 0.936     | 1.814e+03 |
# | 211       | 0.7569    | 0.5197    | 0.3513    | 536.3     |
# | 212       | 0.7487    | 0.9265    | 0.5071    | 1.629e+03 |
# | 213       | 0.7604    | 0.5881    | 0.2899    | 1.457e+03 |
# | 214       | 0.7708    | 0.5623    | 0.05325   | 1.457e+03 |
# | 215       | 0.7652    | 0.7518    | 0.03122   | 1.211e+03 |
# | 216       | 0.7716    | 0.9051    | 0.06487   | 1.457e+03 |
# | 217       | 0.7451    | 0.8442    | 0.8718    | 941.0     |
# | 218       | 0.7667    | 0.6173    | 0.1254    | 415.2     |
# | 219       | 0.7625    | 0.7436    | 0.2688    | 1.457e+03 |
# | 220       | 0.7553    | 0.734     | 0.368     | 591.8     |
# | 221       | 0.7691    | 0.6987    | 0.001823  | 897.0     |
# | 222       | 0.7691    | 0.952     | 0.000917  | 1.457e+03 |
# | 223       | 0.752     | 0.783     | 0.3754    | 415.2     |
# | 224       | 0.7724    | 0.8834    | 0.08052   | 414.9     |
# | 225       | 0.7712    | 0.6243    | 0.01977   | 1.052e+03 |
# | 226       | 0.7471    | 0.8201    | 0.9765    | 829.8     |
# | 227       | 0.756     | 0.9232    | 0.3751    | 573.5     |
# | 228       | 0.7676    | 0.8492    | 0.0227    | 897.2     |
# | 229       | 0.7465    | 0.6576    | 0.6397    | 339.7     |
# | 230       | 0.7688    | 0.5809    | 0.03378   | 863.8     |
# | 231       | 0.7697    | 0.9705    | 0.0354    | 1.875e+03 |
# | 232       | 0.7713    | 0.5572    | 0.06368   | 1.847e+03 |
# | 233       | 0.7703    | 0.9325    | 0.1174    | 1.625e+03 |
# | 234       | 0.7622    | 0.7159    | 0.2424    | 897.1     |
# | 235       | 0.7691    | 0.7982    | 0.01138   | 1.847e+03 |
# | 236       | 0.7465    | 0.8792    | 0.9068    | 1.064e+03 |
# | 237       | 0.7532    | 0.8747    | 0.4923    | 1.224e+03 |
# | 238       | 0.7477    | 0.8097    | 0.6148    | 689.6     |
# | 239       | 0.7457    | 0.8108    | 0.7996    | 944.4     |
# | 240       | 0.7654    | 0.7443    | 0.1477    | 561.3     |
# | 241       | 0.7513    | 0.9599    | 0.6754    | 1.32e+03  |
# | 242       | 0.7719    | 0.6504    | 0.07871   | 1.847e+03 |
# | 243       | 0.7586    | 0.5442    | 0.2982    | 1.847e+03 |
# | 244       | 0.7648    | 0.9609    | 0.1424    | 414.7     |
# | 245       | 0.7669    | 0.9968    | 0.1747    | 1.457e+03 |
# | 246       | 0.7736    | 0.9924    | 0.1519    | 1.269e+03 |
# | 247       | 0.7474    | 0.6126    | 0.6184    | 1.953e+03 |
# | 248       | 0.7726    | 0.8903    | 0.123     | 1.874e+03 |
# | 249       | 0.7698    | 0.6523    | 0.1714    | 1.874e+03 |
# | 250       | 0.7522    | 0.961     | 0.4415    | 1.874e+03 |
# | 251       | 0.7658    | 0.6398    | 0.1436    | 414.9     |
# | 252       | 0.7703    | 0.6122    | 0.01754   | 1.846e+03 |
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 results = rf_bo.maximize(n_iter=200, init_points=20)
#
# File ~/.local/lib/python3.10/site-packages/bayes_opt/bayesian_optimization.py:311, in BayesianOptimization.maximize(self, init_points, n_iter, acquisition_function, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     309     x_probe = self.suggest(util)
#     310     iteration += 1
# --> 311 self.probe(x_probe, lazy=False)
#     313 if self._bounds_transformer and iteration > 0:
#     314     # The bounds transformer should only modify the bounds after
#     315     # the init_points points (only for the true iterations)
#     316     self.set_bounds(
#     317         self._bounds_transformer.transform(self._space))
#
# File ~/.local/lib/python3.10/site-packages/bayes_opt/bayesian_optimization.py:208, in BayesianOptimization.probe(self, params, lazy)
#     206     self._queue.add(params)
#     207 else:
# --> 208     self._space.probe(params)
#     209     self.dispatch(Events.OPTIMIZATION_STEP)
#
# File ~/.local/lib/python3.10/site-packages/bayes_opt/target_space.py:236, in TargetSpace.probe(self, params)
#     234 x = self._as_array(params)
#     235 params = dict(zip(self._keys, x))
# --> 236 target = self.target_func(**params)
#     238 if self._constraint is None:
#     239     self.register(x, target)
#
# Cell In[17], line 10, in bo_params_rf(max_samples, n_estimators, max_features)
#       4 params = {
#       5     'max_samples': max_samples,
#       6     'max_features':max_features,
#       7     'n_estimators':int(n_estimators)
#       8 }
#       9 clf = RandomForestClassifier(max_samples=params['max_samples'],max_features=params['max_features'],n_estimators=params['n_estimators'])
# ---> 10 score = stratified_kfold_score(clf,X_train, y_train, 10)
#      11 return score
#
# Cell In[16], line 10, in stratified_kfold_score(clf, X, y, n_fold)
#       8 x_train_fold, x_test_fold = X[train_index], X[test_index]
#       9 y_train_fold, y_test_fold = y[train_index], y[test_index]
# ---> 10 clf.fit(x_train_fold, y_train_fold)
#      11 y_pred = clf.predict(x_test_fold)
#      12 f1score_test = f1_score(y_pred,y_test_fold)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:340, in BaseForest.fit(self, X, y, sample_weight)
#     313 def fit(self, X, y, sample_weight=None):
#     314     """
#     315     Build a forest of trees from the training set (X, y).
#     316
#    (...)
#     338         Fitted estimator.
#     339     """
# --> 340     self._validate_params()
#     342     # Validate or convert input data
#     343     if issparse(y):
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:600, in BaseEstimator._validate_params(self)
#     592 def _validate_params(self):
#     593     """Validate types and values of constructor parameters
#     594
#     595     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     598     accepted constraints.
#     599     """
# --> 600     validate_parameter_constraints(
#     601         self._parameter_constraints,
#     602         self.get_params(deep=False),
#     603         caller_name=self.__class__.__name__,
#     604     )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:97, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      91 else:
#      92     constraints_str = (
#      93         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      94         f" {constraints[-1]}"
#      95     )
# ---> 97 raise InvalidParameterError(
#      98     f"The {param_name!r} parameter of {caller_name} must be"
#      99     f" {constraints_str}. Got {param_val!r} instead."
#     100 )
#
# InvalidParameterError: The 'max_samples' parameter of RandomForestClassifier must be None, a float in the range (0.0, 1.0] or an int in the range [1, inf). Got 0.0 instead.

# %%
results = rf_bo.maximize(n_iter=200, init_points=20)
# Out:
# |   iter    |  target   | max_fe... | max_sa... | n_esti... |
# -------------------------------------------------------------
# | 253       | 0.7473    | 0.8633    | 0.9001    | 1.602e+03 |
# | 254       | 0.7619    | 0.7996    | 0.2911    | 472.5     |
# | 255       | 0.7487    | 0.6676    | 0.6576    | 332.0     |
# | 256       | 0.7585    | 0.5275    | 0.3232    | 1.263e+03 |
# | 257       | 0.7607    | 0.9269    | 0.2871    | 511.5     |
# | 258       | 0.7436    | 0.567     | 0.9947    | 523.1     |
# | 259       | 0.7447    | 0.6588    | 0.5683    | 216.8     |
# | 260       | 0.746     | 0.9503    | 0.9772    | 1.202e+03 |
# | 261       | 0.7557    | 0.5424    | 0.333     | 1.511e+03 |
# | 262       | 0.7501    | 0.5712    | 0.5525    | 691.5     |
# | 263       | 0.7464    | 0.9872    | 0.6678    | 660.2     |
# | 264       | 0.7457    | 0.5542    | 0.7762    | 1.608e+03 |
# | 265       | 0.743     | 0.8808    | 0.9144    | 1.386e+03 |
# | 266       | 0.7667    | 0.7842    | 0.2018    | 1.457e+03 |
# | 267       | 0.7452    | 0.9761    | 0.89      | 1.988e+03 |
# | 268       | 0.7524    | 0.9094    | 0.5451    | 1.012e+03 |
# | 269       | 0.7486    | 0.9453    | 0.9733    | 1.268e+03 |
# | 270       | 0.7562    | 0.683     | 0.3231    | 1.769e+03 |
# | 271       | 0.7477    | 0.6078    | 0.7349    | 858.1     |
# | 272       | 0.7463    | 0.9008    | 0.7827    | 1.462e+03 |
# | 273       | 0.7545    | 0.5482    | 0.3114    | 426.9     |
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 results = rf_bo.maximize(n_iter=200, init_points=20)
#
# File ~/.local/lib/python3.10/site-packages/bayes_opt/bayesian_optimization.py:311, in BayesianOptimization.maximize(self, init_points, n_iter, acquisition_function, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     309     x_probe = self.suggest(util)
#     310     iteration += 1
# --> 311 self.probe(x_probe, lazy=False)
#     313 if self._bounds_transformer and iteration > 0:
#     314     # The bounds transformer should only modify the bounds after
#     315     # the init_points points (only for the true iterations)
#     316     self.set_bounds(
#     317         self._bounds_transformer.transform(self._space))
#
# File ~/.local/lib/python3.10/site-packages/bayes_opt/bayesian_optimization.py:208, in BayesianOptimization.probe(self, params, lazy)
#     206     self._queue.add(params)
#     207 else:
# --> 208     self._space.probe(params)
#     209     self.dispatch(Events.OPTIMIZATION_STEP)
#
# File ~/.local/lib/python3.10/site-packages/bayes_opt/target_space.py:236, in TargetSpace.probe(self, params)
#     234 x = self._as_array(params)
#     235 params = dict(zip(self._keys, x))
# --> 236 target = self.target_func(**params)
#     238 if self._constraint is None:
#     239     self.register(x, target)
#
# Cell In[17], line 10, in bo_params_rf(max_samples, n_estimators, max_features)
#       4 params = {
#       5     'max_samples': max_samples,
#       6     'max_features':max_features,
#       7     'n_estimators':int(n_estimators)
#       8 }
#       9 clf = RandomForestClassifier(max_samples=params['max_samples'],max_features=params['max_features'],n_estimators=params['n_estimators'])
# ---> 10 score = stratified_kfold_score(clf,X_train, y_train, 10)
#      11 return score
#
# Cell In[16], line 10, in stratified_kfold_score(clf, X, y, n_fold)
#       8 x_train_fold, x_test_fold = X[train_index], X[test_index]
#       9 y_train_fold, y_test_fold = y[train_index], y[test_index]
# ---> 10 clf.fit(x_train_fold, y_train_fold)
#      11 y_pred = clf.predict(x_test_fold)
#      12 f1score_test = f1_score(y_pred,y_test_fold)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:340, in BaseForest.fit(self, X, y, sample_weight)
#     313 def fit(self, X, y, sample_weight=None):
#     314     """
#     315     Build a forest of trees from the training set (X, y).
#     316
#    (...)
#     338         Fitted estimator.
#     339     """
# --> 340     self._validate_params()
#     342     # Validate or convert input data
#     343     if issparse(y):
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:600, in BaseEstimator._validate_params(self)
#     592 def _validate_params(self):
#     593     """Validate types and values of constructor parameters
#     594
#     595     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     598     accepted constraints.
#     599     """
# --> 600     validate_parameter_constraints(
#     601         self._parameter_constraints,
#     602         self.get_params(deep=False),
#     603         caller_name=self.__class__.__name__,
#     604     )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:97, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      91 else:
#      92     constraints_str = (
#      93         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      94         f" {constraints[-1]}"
#      95     )
# ---> 97 raise InvalidParameterError(
#      98     f"The {param_name!r} parameter of {caller_name} must be"
#      99     f" {constraints_str}. Got {param_val!r} instead."
#     100 )
#
# InvalidParameterError: The 'max_samples' parameter of RandomForestClassifier must be None, a float in the range (0.0, 1.0] or an int in the range [1, inf). Got 0.0 instead.

# %%
results = rf_bo.maximize(n_iter=5, init_points=20)
# Out:
# |   iter    |  target   | max_fe... | max_sa... | n_esti... |
# -------------------------------------------------------------
# | 274       | 0.7501    | 0.8114    | 0.4937    | 1.713e+03 |
# | 275       | 0.7486    | 0.856     | 0.4439    | 255.9     |
# | 276       | 0.7486    | 0.6816    | 0.7307    | 1.056e+03 |
# | 277       | 0.7462    | 0.6722    | 0.6409    | 427.2     |
# | 278       | 0.7403    | 0.5857    | 0.7371    | 428.7     |
# | 279       | 0.7502    | 0.6848    | 0.6043    | 385.6     |
# | 280       | 0.7435    | 0.9012    | 0.9456    | 1.962e+03 |
# | 281       | 0.7521    | 0.9406    | 0.6277    | 1.875e+03 |
# | 282       | 0.7479    | 0.8624    | 0.7167    | 273.9     |
# | 283       | 0.7566    | 0.7197    | 0.2821    | 803.0     |
# | 284       | 0.7481    | 0.5418    | 0.7608    | 1.117e+03 |
# | 285       | 0.7468    | 0.8305    | 0.6303    | 867.7     |
# | 286       | 0.7553    | 0.7234    | 0.4151    | 1.065e+03 |
# | 287       | 0.7586    | 0.9917    | 0.3734    | 222.3     |
# | 288       | 0.7489    | 0.961     | 0.8733    | 833.1     |
# | 289       | 0.7569    | 0.8151    | 0.3578    | 583.1     |
# | 290       | 0.7507    | 0.6117    | 0.4196    | 331.2     |
# | 291       | 0.745     | 0.8254    | 0.7557    | 1.878e+03 |
# | 292       | 0.7592    | 0.6882    | 0.2969    | 869.5     |
# | 293       | 0.7462    | 0.9138    | 0.9011    | 969.1     |
# | 294       | 0.7691    | 0.5506    | 0.006154  | 1.847e+03 |
# | 295       | 0.7698    | 0.653     | 0.03081   | 1.269e+03 |
# | 296       | 0.7458    | 0.7866    | 0.5299    | 430.7     |
# | 297       | 0.7499    | 0.5502    | 0.8878    | 1.184e+03 |
# | 298       | 0.7694    | 0.6439    | 0.07724   | 1.625e+03 |
# =============================================================

# %%
# !pip3 install pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
import pickle

# %%
with open('result.pkl', 'wb') as fp:
  pickle.dump(results.res, fp)
