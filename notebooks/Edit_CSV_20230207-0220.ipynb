# %%
import pandas as pd

# %%
df1 = pd.read_csv('old_filename/20230207-20230213.csv', header = None, names = ["created_at", "id", "text", "author_id","edit_history_tweet_ids", "public_metrics"])
df1.head()
# Out:
#                  created_at                   id  \
# 0  2023-02-12T14:58:51.000Z  1624785106333310984
# 1  2023-02-12T14:58:18.000Z  1624784970509348866
# 2  2023-02-12T14:58:00.000Z  1624784895871680512
# 3  2023-02-12T14:56:48.000Z  1624784592413532160
# 4  2023-02-12T14:56:06.000Z  1624784417171419140
#
#                                                 text            author_id  \
# 0           @cve_0q @gorgeous4ew انت الي ماسويت شئ !  1530877110226665472
# 1  RT @_0xf4n9x_: CVE-2023-0669 GoAnywhere MFT De...  1388217926541447169
# 2  RT @pdnuclei: Scanning for GoAnywhere MFT - Re...  1388217926541447169
# 3  RT @pdnuclei: Scanning for GoAnywhere MFT - Re...            941026441
# 4  PoC Available:\n\n@github : https://t.co/RBVYq...  1322315722287099909
#
#     edit_history_tweet_ids                                     public_metrics
# 0  ['1624785106333310984']  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# ...

# %%
df2 = pd.read_csv('old_filename/20230213-20230219.csv', header = None, names = ["text", "author_id", "id","created_at",  "public_metrics", "edit_history_tweet_ids"])
df2.head()
# Out:
#                                                 text            author_id  \
# 0  AMD Ryzen Masterに脆弱性。システムが完全に制御される恐れ。2.10.1.22...            155942328
# 1  💰💰💰💰💰💰💰💰💰💰💰💰\n🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥\n\nTrade-Ideas is ...  1527831839255285760
# 2  RT @Horizon3Attack: CVE-2022-39952, announced ...  1620281239587495939
# 3  🚨 NEW: CVE-2023-22246 🚨 Adobe Animate versions...   904129001723011072
# 4  RT @ldsopreload: someone has made basically an...   892148661609746432
#
#                     id                created_at  \
# 0  1626959611906658304  2023-02-18T14:59:33.000Z
# 1  1626959438325116931  2023-02-18T14:58:52.000Z
# 2  1626959335342448640  2023-02-18T14:58:27.000Z
# 3  1626958943468548099  2023-02-18T14:56:54.000Z
# 4  1626958932961787904  2023-02-18T14:56:51.000Z
#
#                                       public_metrics   edit_history_tweet_ids
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_c...  ['1626959611906658304']
# ...

# %%
df2 = df2.loc[:, ["created_at", "id", "text", "author_id","edit_history_tweet_ids", "public_metrics"]]
df2.head()
# Out:
#                  created_at                   id  \
# 0  2023-02-18T14:59:33.000Z  1626959611906658304
# 1  2023-02-18T14:58:52.000Z  1626959438325116931
# 2  2023-02-18T14:58:27.000Z  1626959335342448640
# 3  2023-02-18T14:56:54.000Z  1626958943468548099
# 4  2023-02-18T14:56:51.000Z  1626958932961787904
#
#                                                 text            author_id  \
# 0  AMD Ryzen Masterに脆弱性。システムが完全に制御される恐れ。2.10.1.22...            155942328
# 1  💰💰💰💰💰💰💰💰💰💰💰💰\n🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥\n\nTrade-Ideas is ...  1527831839255285760
# 2  RT @Horizon3Attack: CVE-2022-39952, announced ...  1620281239587495939
# 3  🚨 NEW: CVE-2023-22246 🚨 Adobe Animate versions...   904129001723011072
# 4  RT @ldsopreload: someone has made basically an...   892148661609746432
#
#     edit_history_tweet_ids                                     public_metrics
# 0  ['1626959611906658304']  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...

# %%
df3 = pd.read_csv('old_filename/20230219-20230221.csv', header = 0 )
df3.head()
# Out:
#                   created_at                   id  \
# 0  2023-02-20 14:59:15+00:00  1627684312001781763
# 1  2023-02-20 14:58:55+00:00  1627684229315448834
# 2  2023-02-20 14:57:31+00:00  1627683876423274496
# 3  2023-02-20 14:51:38+00:00  1627682392965251074
# 4  2023-02-20 14:50:38+00:00  1627682141696888832
#
#                                                 text            author_id  \
# 0  RT @Dinosn: CVE-2022-27677: AMD Ryzen Master P...  1563876813503434752
# 1  $cve *Top analyst target price for next week &...  1540283817176727552
# 2  RT @CyberWarship: " CVSS Scores &amp; Vulnerab...  1563876813503434752
# 3  RT @Haqiqatjou: Here is Roberts co writing an ...  1480099215644581889
# 4  RT @solminingpunk: Some of the notable flaws r...  1458981231903887360
#
#   edit_history_tweet_ids                                     public_metrics
# 0  [1627684312001781763]  {'retweet_count': 17, 'reply_count': 0, 'like_...
# ...

# %%
print(len(df1))
print(len(df2))
print(len(df3))
# Out:
# 10520
# 18361
# 2829

# %%
df1.to_csv("20230207-20230212.csv", index = False, header = True)

# %%
df2.to_csv("20230213-20230218.csv", index = False, header = True)

# %%
df3.to_csv("20230219-20230220.csv", index = False, header = True)
