# %%
# 全てのCVEについてtsfreshを適用して48時間分の時系列丸め込みデータの特徴量化を図る
import pandas as pd

# %%
# CSV読み込み時にDatetimeIndexを設定
# pd.read_csv()の引数index_colにインデックスとして使う日時データの列名（または0始まりの列番号）を指定し、引数parse_datesをTrueとする。
df = pd.read_csv('51420_labeled_data_rounded_20230326.csv', index_col = 1, parse_dates = True )
df
# Out:
#                            Unnamed: 0                 created_at  \
# rd_created_at
# 2023-02-06 15:00:00+00:00           0  2023-02-06 15:00:35+00:00
# 2023-02-06 15:00:00+00:00           1  2023-02-06 15:01:32+00:00
# 2023-02-06 15:00:00+00:00           2  2023-02-06 15:02:17+00:00
# 2023-02-06 15:00:00+00:00           3  2023-02-06 15:02:36+00:00
# 2023-02-06 15:00:00+00:00           4  2023-02-06 15:03:33+00:00
# ...                               ...                        ...
# 2023-03-26 14:00:00+00:00       51415  2023-03-26 14:55:04+00:00
# 2023-03-26 14:00:00+00:00       51416  2023-03-26 14:56:54+00:00
# 2023-03-26 14:00:00+00:00       51417  2023-03-26 14:56:55+00:00
# 2023-03-26 14:00:00+00:00       51418  2023-03-26 14:58:45+00:00
# 2023-03-26 14:00:00+00:00       51419  2023-03-26 14:59:10+00:00
#
#                                             id  \
# rd_created_at
# 2023-02-06 15:00:00+00:00  1622611217725399042
# 2023-02-06 15:00:00+00:00  1622611455823732736
# 2023-02-06 15:00:00+00:00  1622611643040423939
# 2023-02-06 15:00:00+00:00  1622611724770877443
# 2023-02-06 15:00:00+00:00  1622611963275780096
# ...                                        ...
# 2023-03-26 14:00:00+00:00  1640004446057840646
# 2023-03-26 14:00:00+00:00  1640004907666231296
# 2023-03-26 14:00:00+00:00  1640004909969063939
# 2023-03-26 14:00:00+00:00  1640005374831984641
# 2023-03-26 14:00:00+00:00  1640005479223967746
#
#                                                                         text  \
# rd_created_at
# 2023-02-06 15:00:00+00:00  RT @0xor0ne: CVE-2021-27365: analysis and expl...
# 2023-02-06 15:00:00+00:00  CVE-2021-21974 https://t.co/OqV4Ki8gRI #Harsia...
# 2023-02-06 15:00:00+00:00  RT @SecurityBDog: Is CVE-2022-42889 important ...
# 2023-02-06 15:00:00+00:00  RT @0xor0ne: CVE-2022-47949: analysis and expl...
# 2023-02-06 15:00:00+00:00  CVE-2022-44268 https://t.co/JWNV88HSaa #Harsia...
# ...                                                                      ...
# 2023-03-26 14:00:00+00:00  RT @threatmeter: CVE-2021-42761 | Fortinet For...
# 2023-03-26 14:00:00+00:00  ثغرة حديثة "CVE-2022-3229"\n #منيع https://t.c...
# 2023-03-26 14:00:00+00:00  🚨 NEW: CVE-2023-1445 🚨 A vulnerability classif...
# 2023-03-26 14:00:00+00:00  RT @CVEnew: CVE-2023-1105 External Control of ...
# 2023-03-26 14:00:00+00:00  ثغرة حديثة "CVE-2022-46496"\n #منيع https://t....
#
#                               author_id   edit_history_tweet_ids  \
# rd_created_at
# 2023-02-06 15:00:00+00:00  1.949128e+07  ['1622611217725399042']
# 2023-02-06 15:00:00+00:00  1.083501e+18  ['1622611455823732736']
# 2023-02-06 15:00:00+00:00  1.359569e+18  ['1622611643040423939']
# 2023-02-06 15:00:00+00:00  1.621510e+18  ['1622611724770877443']
# 2023-02-06 15:00:00+00:00  1.083501e+18  ['1622611963275780096']
# ...                                 ...                      ...
# 2023-03-26 14:00:00+00:00  1.900976e+08    [1640004446057840646]
# 2023-03-26 14:00:00+00:00  1.633455e+18    [1640004907666231296]
# 2023-03-26 14:00:00+00:00  9.041290e+17    [1640004909969063939]
# 2023-03-26 14:00:00+00:00  1.493214e+18    [1640005374831984641]
# 2023-03-26 14:00:00+00:00  1.633455e+18    [1640005479223967746]
#
#                                                               public_metrics  \
# rd_created_at
# 2023-02-06 15:00:00+00:00  {'retweet_count': 107, 'reply_count': 0, 'like...
# 2023-02-06 15:00:00+00:00  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2023-02-06 15:00:00+00:00  {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 2023-02-06 15:00:00+00:00  {'retweet_count': 71, 'reply_count': 0, 'like_...
# 2023-02-06 15:00:00+00:00  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...                                                                      ...
# 2023-03-26 14:00:00+00:00  {'retweet_count': 14, 'reply_count': 0, 'like_...
# 2023-03-26 14:00:00+00:00  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2023-03-26 14:00:00+00:00  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2023-03-26 14:00:00+00:00  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 2023-03-26 14:00:00+00:00  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                       CVE baseSeverity  baseScore  flag_CR  \
# rd_created_at
# 2023-02-06 15:00:00+00:00  CVE-2021-27365         HIGH        7.8        0
# 2023-02-06 15:00:00+00:00  CVE-2021-21974         HIGH        8.8        0
# 2023-02-06 15:00:00+00:00  CVE-2022-42889     CRITICAL        9.8        1
# 2023-02-06 15:00:00+00:00  CVE-2022-47949     CRITICAL        9.8        1
# 2023-02-06 15:00:00+00:00  CVE-2022-44268       MEDIUM        6.5        0
# ...                                   ...          ...        ...      ...
# 2023-03-26 14:00:00+00:00  CVE-2021-42761     CRITICAL        9.8        1
# 2023-03-26 14:00:00+00:00   CVE-2022-3229     CRITICAL        9.8        1
# 2023-03-26 14:00:00+00:00   CVE-2023-1445       MEDIUM        5.5        0
# 2023-03-26 14:00:00+00:00   CVE-2023-1105         HIGH        8.1        0
# 2023-03-26 14:00:00+00:00  CVE-2022-46496       MEDIUM        5.9        0
#
#                            flag_H
# rd_created_at
# 2023-02-06 15:00:00+00:00       1
# 2023-02-06 15:00:00+00:00       1
# 2023-02-06 15:00:00+00:00       1
# 2023-02-06 15:00:00+00:00       1
# 2023-02-06 15:00:00+00:00       0
# ...                           ...
# 2023-03-26 14:00:00+00:00       1
# 2023-03-26 14:00:00+00:00       1
# 2023-03-26 14:00:00+00:00       0
# 2023-03-26 14:00:00+00:00       1
# 2023-03-26 14:00:00+00:00       0
#
# [51420 rows x 12 columns]

# %%
print(type(df.index))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %% [markdown]
# ## Create the Time series data

# %%
CVE_list = df['CVE'].unique()

# %%
len(CVE_list)
# Out:
# 1677

# %%
df_test = df
df_test.drop(columns = ['Unnamed: 0', 'created_at', 'id', 'text', 'author_id',
       'edit_history_tweet_ids', 'public_metrics', 'baseSeverity',
       'baseScore', 'flag_H', 'flag_CR'], inplace = True)
df_test
# Out:
#                                       CVE
# rd_created_at
# 2023-02-06 15:00:00+00:00  CVE-2021-27365
# 2023-02-06 15:00:00+00:00  CVE-2021-21974
# 2023-02-06 15:00:00+00:00  CVE-2022-42889
# 2023-02-06 15:00:00+00:00  CVE-2022-47949
# 2023-02-06 15:00:00+00:00  CVE-2022-44268
# ...                                   ...
# 2023-03-26 14:00:00+00:00  CVE-2021-42761
# 2023-03-26 14:00:00+00:00   CVE-2022-3229
# 2023-03-26 14:00:00+00:00   CVE-2023-1445
# 2023-03-26 14:00:00+00:00   CVE-2023-1105
# 2023-03-26 14:00:00+00:00  CVE-2022-46496
#
# [51420 rows x 1 columns]

# %%
df_test.groupby(['rd_created_at','CVE'])['CVE'].count()
# Out:
# rd_created_at              CVE
# 2023-02-06 15:00:00+00:00  CVE-2020-3992      1
#                            CVE-2021-21974     7
#                            CVE-2021-27365    18
#                            CVE-2021-36224    10
#                            CVE-2021-36225     9
#                                              ..
# 2023-03-26 14:00:00+00:00  CVE-2023-1445      1
#                            CVE-2023-1453      1
#                            CVE-2023-23397    10
#                            CVE-2023-23752     1
#                            CVE-2023-28432     2
# Name: CVE, Length: 21427, dtype: int64

# %%
print(type(df_test.groupby(['rd_created_at','CVE'])['CVE'].count()))
# Out:
# <class 'pandas.core.series.Series'>

# %%
pd.DataFrame(df_test.groupby(['rd_created_at','CVE'])['CVE'].count())
# Out:
#                                           CVE
# rd_created_at             CVE
# 2023-02-06 15:00:00+00:00 CVE-2020-3992     1
#                           CVE-2021-21974    7
#                           CVE-2021-27365   18
#                           CVE-2021-36224   10
#                           CVE-2021-36225    9
# ...                                       ...
# 2023-03-26 14:00:00+00:00 CVE-2023-1445     1
#                           CVE-2023-1453     1
#                           CVE-2023-23397   10
#                           CVE-2023-23752    1
#                           CVE-2023-28432    2
#
# [21427 rows x 1 columns]

# %%
df_counted = pd.DataFrame(df_test.groupby(['rd_created_at','CVE'])['CVE'].count())
print(df_counted)
# Out:
#                                           CVE
# rd_created_at             CVE
# 2023-02-06 15:00:00+00:00 CVE-2020-3992     1
#                           CVE-2021-21974    7
#                           CVE-2021-27365   18
#                           CVE-2021-36224   10
#                           CVE-2021-36225    9
# ...                                       ...
# 2023-03-26 14:00:00+00:00 CVE-2023-1445     1
#                           CVE-2023-1453     1
#                           CVE-2023-23397   10
#                           CVE-2023-23752    1
#                           CVE-2023-28432    2
#
# [21427 rows x 1 columns]

# %%
print(type(df_counted))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_counted.rename(columns = {'CVE':'count'}, inplace = True)

# %%
df_counted
# Out:
#                                           count
# rd_created_at             CVE
# 2023-02-06 15:00:00+00:00 CVE-2020-3992       1
#                           CVE-2021-21974      7
#                           CVE-2021-27365     18
#                           CVE-2021-36224     10
#                           CVE-2021-36225      9
# ...                                         ...
# 2023-03-26 14:00:00+00:00 CVE-2023-1445       1
#                           CVE-2023-1453       1
#                           CVE-2023-23397     10
#                           CVE-2023-23752      1
#                           CVE-2023-28432      2
#
# [21427 rows x 1 columns]

# %%
df_counted.reset_index(level = -1, inplace = True)
df_counted
# Out:
#                                       CVE  count
# rd_created_at
# 2023-02-06 15:00:00+00:00   CVE-2020-3992      1
# 2023-02-06 15:00:00+00:00  CVE-2021-21974      7
# 2023-02-06 15:00:00+00:00  CVE-2021-27365     18
# 2023-02-06 15:00:00+00:00  CVE-2021-36224     10
# 2023-02-06 15:00:00+00:00  CVE-2021-36225      9
# ...                                   ...    ...
# 2023-03-26 14:00:00+00:00   CVE-2023-1445      1
# 2023-03-26 14:00:00+00:00   CVE-2023-1453      1
# 2023-03-26 14:00:00+00:00  CVE-2023-23397     10
# 2023-03-26 14:00:00+00:00  CVE-2023-23752      1
# 2023-03-26 14:00:00+00:00  CVE-2023-28432      2
#
# [21427 rows x 2 columns]

# %%
df_48hour = pd.DataFrame()

# %%
import datetime
import numpy as np
for i, cve in enumerate(CVE_list):
    
    # create null DF
    df_48hour_ = pd.DataFrame()
    
    # Define the start & end time (48hours) for the cve-id
    start_time = df_counted[df_counted['CVE'] == cve].index[0]
    end_time = start_time + datetime.timedelta(hours = 48)

    # Create a temporary Dataframe for the cve
    df_48hour_ = df_counted[df_counted['CVE'] == cve].loc[start_time:end_time]

    # Concatenate temporary Dataframes
    if (i == 0):
        df_48hour = df_48hour_
        
    else:
        df_48hour = pd.concat([df_48hour, df_48hour_])
df_48hour
# Out:
#                                       CVE  count
# rd_created_at
# 2023-02-06 15:00:00+00:00  CVE-2021-27365     18
# 2023-02-06 16:00:00+00:00  CVE-2021-27365      7
# 2023-02-06 17:00:00+00:00  CVE-2021-27365      7
# 2023-02-06 18:00:00+00:00  CVE-2021-27365      4
# 2023-02-06 19:00:00+00:00  CVE-2021-27365      3
# ...                                   ...    ...
# 2023-03-25 16:00:00+00:00   CVE-2023-1629      1
# 2023-03-26 04:00:00+00:00   CVE-2023-1629      1
# 2023-03-26 08:00:00+00:00   CVE-2023-1629      3
# 2023-03-26 10:00:00+00:00   CVE-2023-1629      1
# 2023-03-25 20:00:00+00:00  CVE-2022-35405     16
#
# [10972 rows x 2 columns]

# %%
df_ = df_48hour.reset_index()
df_
# Out:
#                   rd_created_at             CVE  count
# 0     2023-02-06 15:00:00+00:00  CVE-2021-27365     18
# 1     2023-02-06 16:00:00+00:00  CVE-2021-27365      7
# 2     2023-02-06 17:00:00+00:00  CVE-2021-27365      7
# 3     2023-02-06 18:00:00+00:00  CVE-2021-27365      4
# 4     2023-02-06 19:00:00+00:00  CVE-2021-27365      3
# ...                         ...             ...    ...
# 10967 2023-03-25 16:00:00+00:00   CVE-2023-1629      1
# 10968 2023-03-26 04:00:00+00:00   CVE-2023-1629      1
# 10969 2023-03-26 08:00:00+00:00   CVE-2023-1629      3
# 10970 2023-03-26 10:00:00+00:00   CVE-2023-1629      1
# 10971 2023-03-25 20:00:00+00:00  CVE-2022-35405     16
#
# [10972 rows x 3 columns]

# %%
from tsfresh import extract_features, extract_relevant_features
df_test_features = extract_features(df_, column_id = 'CVE', column_sort = 'rd_created_at', column_value = 'count')
df_test_features
# Out:
# Feature Extraction:  50%|█████     | 5/10 [00:18<00:19,  3.86s/it]
