# %%
import pandas as pd

# %%
# CSV読み込み時にDatetimeIndexを設定
# pd.read_csv()の引数index_colにインデックスとして使う日時データの列名（または0始まりの列番号）を指定し、引数parse_datesをTrueとする。
df = pd.read_csv('51420_labeled_data_rounded_20230326.csv', index_col = 1, parse_dates = True )
df
# Out:
#                            Unnamed: 0                 created_at  \
# rd_created_at
# 2023-02-06 15:00:00+00:00           0  2023-02-06 15:00:35+00:00
# 2023-02-06 15:00:00+00:00           1  2023-02-06 15:01:32+00:00
# 2023-02-06 15:00:00+00:00           2  2023-02-06 15:02:17+00:00
# 2023-02-06 15:00:00+00:00           3  2023-02-06 15:02:36+00:00
# 2023-02-06 15:00:00+00:00           4  2023-02-06 15:03:33+00:00
# ...                               ...                        ...
# 2023-03-26 14:00:00+00:00       51415  2023-03-26 14:55:04+00:00
# 2023-03-26 14:00:00+00:00       51416  2023-03-26 14:56:54+00:00
# 2023-03-26 14:00:00+00:00       51417  2023-03-26 14:56:55+00:00
# 2023-03-26 14:00:00+00:00       51418  2023-03-26 14:58:45+00:00
# 2023-03-26 14:00:00+00:00       51419  2023-03-26 14:59:10+00:00
#
#                                             id  \
# rd_created_at
# 2023-02-06 15:00:00+00:00  1622611217725399042
# 2023-02-06 15:00:00+00:00  1622611455823732736
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2023-02-06 15:00:00+00:00', '2023-02-06 15:00:00+00:00',
#                '2023-02-06 15:00:00+00:00', '2023-02-06 15:00:00+00:00',
#                '2023-02-06 15:00:00+00:00', '2023-02-06 15:00:00+00:00',
#                '2023-02-06 15:00:00+00:00', '2023-02-06 15:00:00+00:00',
#                '2023-02-06 15:00:00+00:00', '2023-02-06 15:00:00+00:00',
#                ...
#                '2023-03-26 14:00:00+00:00', '2023-03-26 14:00:00+00:00',
#                '2023-03-26 14:00:00+00:00', '2023-03-26 14:00:00+00:00',
#                '2023-03-26 14:00:00+00:00', '2023-03-26 14:00:00+00:00',
#                '2023-03-26 14:00:00+00:00', '2023-03-26 14:00:00+00:00',
#                '2023-03-26 14:00:00+00:00', '2023-03-26 14:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='rd_created_at', length=51420, freq=None)

# %%
CVE_list = df['CVE'].to_list()
CVE_list[:5]
# Out:
# ['CVE-2021-27365',
#  'CVE-2021-21974',
#  'CVE-2022-42889',
#  'CVE-2022-47949',
#  'CVE-2022-44268']

# %%
df[df['CVE'] == CVE_list[0]]
# Out:
#                            Unnamed: 0                 created_at  \
# rd_created_at
# 2023-02-06 15:00:00+00:00           0  2023-02-06 15:00:35+00:00
# 2023-02-06 15:00:00+00:00          20  2023-02-06 15:10:24+00:00
# 2023-02-06 15:00:00+00:00          21  2023-02-06 15:12:02+00:00
# 2023-02-06 15:00:00+00:00          29  2023-02-06 15:17:21+00:00
# 2023-02-06 15:00:00+00:00          30  2023-02-06 15:18:24+00:00
# ...                               ...                        ...
# 2023-02-08 12:00:00+00:00        1655  2023-02-08 12:08:01+00:00
# 2023-02-08 14:00:00+00:00        1706  2023-02-08 14:08:03+00:00
# 2023-02-08 16:00:00+00:00        1749  2023-02-08 16:08:01+00:00
# 2023-02-09 09:00:00+00:00        2224  2023-02-09 09:17:08+00:00
# 2023-02-09 12:00:00+00:00        2334  2023-02-09 12:01:30+00:00
#
#                                             id  \
# rd_created_at
# 2023-02-06 15:00:00+00:00  1622611217725399042
# 2023-02-06 15:00:00+00:00  1622613688325660675
# ...

# %%
# CVE-2021-27365の最初の48時間のデータを抽出する
df[df['CVE'] == CVE_list[0]].loc['2023-02-06 15:00:00+00:00':'2023-02-08 15:00:00+00:00']
# Out:
#                            Unnamed: 0                 created_at  \
# rd_created_at
# 2023-02-06 15:00:00+00:00           0  2023-02-06 15:00:35+00:00
# 2023-02-06 15:00:00+00:00          20  2023-02-06 15:10:24+00:00
# 2023-02-06 15:00:00+00:00          21  2023-02-06 15:12:02+00:00
# 2023-02-06 15:00:00+00:00          29  2023-02-06 15:17:21+00:00
# 2023-02-06 15:00:00+00:00          30  2023-02-06 15:18:24+00:00
# ...                               ...                        ...
# 2023-02-08 08:00:00+00:00        1544  2023-02-08 08:18:17+00:00
# 2023-02-08 10:00:00+00:00        1600  2023-02-08 10:08:03+00:00
# 2023-02-08 10:00:00+00:00        1612  2023-02-08 10:51:22+00:00
# 2023-02-08 12:00:00+00:00        1655  2023-02-08 12:08:01+00:00
# 2023-02-08 14:00:00+00:00        1706  2023-02-08 14:08:03+00:00
#
#                                             id  \
# rd_created_at
# 2023-02-06 15:00:00+00:00  1622611217725399042
# 2023-02-06 15:00:00+00:00  1622613688325660675
# ...

# %%
start_time = df[df['CVE'] == CVE_list[0]].index[0]
print(start_time)
# Out:
# 2023-02-06 15:00:00+00:00

# %%
print(type(start_time))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
import datetime
end_time = start_time + datetime.timedelta(hours = 48)
print(end_time)
# Out:
# 2023-02-08 15:00:00+00:00

# %%
# CVE-2021-27365の最初の48時間のデータを抽出する using timedelta
df[df['CVE'] == CVE_list[0]].loc[start_time:end_time]
# Out:
#                            Unnamed: 0                 created_at  \
# rd_created_at
# 2023-02-06 15:00:00+00:00           0  2023-02-06 15:00:35+00:00
# 2023-02-06 15:00:00+00:00          20  2023-02-06 15:10:24+00:00
# 2023-02-06 15:00:00+00:00          21  2023-02-06 15:12:02+00:00
# 2023-02-06 15:00:00+00:00          29  2023-02-06 15:17:21+00:00
# 2023-02-06 15:00:00+00:00          30  2023-02-06 15:18:24+00:00
# ...                               ...                        ...
# 2023-02-08 08:00:00+00:00        1544  2023-02-08 08:18:17+00:00
# 2023-02-08 10:00:00+00:00        1600  2023-02-08 10:08:03+00:00
# 2023-02-08 10:00:00+00:00        1612  2023-02-08 10:51:22+00:00
# 2023-02-08 12:00:00+00:00        1655  2023-02-08 12:08:01+00:00
# 2023-02-08 14:00:00+00:00        1706  2023-02-08 14:08:03+00:00
#
#                                             id  \
# rd_created_at
# 2023-02-06 15:00:00+00:00  1622611217725399042
# 2023-02-06 15:00:00+00:00  1622613688325660675
# ...

# %%
# !pip3 install tsfresh
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.2/136.2 kB 6.4 MB/s eta 0:00:00
# ...

# %%
df_test = df[df['CVE'] == CVE_list[0]].loc[start_time:end_time].copy()
df_test
# Out:
#                            Unnamed: 0                 created_at  \
# rd_created_at
# 2023-02-06 15:00:00+00:00           0  2023-02-06 15:00:35+00:00
# 2023-02-06 15:00:00+00:00          20  2023-02-06 15:10:24+00:00
# 2023-02-06 15:00:00+00:00          21  2023-02-06 15:12:02+00:00
# 2023-02-06 15:00:00+00:00          29  2023-02-06 15:17:21+00:00
# 2023-02-06 15:00:00+00:00          30  2023-02-06 15:18:24+00:00
# ...                               ...                        ...
# 2023-02-08 08:00:00+00:00        1544  2023-02-08 08:18:17+00:00
# 2023-02-08 10:00:00+00:00        1600  2023-02-08 10:08:03+00:00
# 2023-02-08 10:00:00+00:00        1612  2023-02-08 10:51:22+00:00
# 2023-02-08 12:00:00+00:00        1655  2023-02-08 12:08:01+00:00
# 2023-02-08 14:00:00+00:00        1706  2023-02-08 14:08:03+00:00
#
#                                             id  \
# rd_created_at
# 2023-02-06 15:00:00+00:00  1622611217725399042
# 2023-02-06 15:00:00+00:00  1622613688325660675
# ...

# %%
df_test.columns
# Out:
# Index(['Unnamed: 0', 'created_at', 'id', 'text', 'author_id',
#        'edit_history_tweet_ids', 'public_metrics', 'CVE', 'baseSeverity',
#        'baseScore', 'flag_CR', 'flag_H'],
#       dtype='object')

# %%
df_test.drop(columns = ['Unnamed: 0', 'created_at', 'id', 'text', 'author_id',
       'edit_history_tweet_ids', 'public_metrics', 'baseSeverity',
       'baseScore', 'flag_H'], inplace = True)
df_test
# Out:
#                                       CVE  flag_CR
# rd_created_at
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# ...                                   ...      ...
# 2023-02-08 08:00:00+00:00  CVE-2021-27365        0
# 2023-02-08 10:00:00+00:00  CVE-2021-27365        0
# 2023-02-08 10:00:00+00:00  CVE-2021-27365        0
# 2023-02-08 12:00:00+00:00  CVE-2021-27365        0
# 2023-02-08 14:00:00+00:00  CVE-2021-27365        0
#
# [113 rows x 2 columns]

# %%
df_test
# Out:
#                                       CVE  flag_CR
# rd_created_at
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# ...                                   ...      ...
# 2023-02-08 08:00:00+00:00  CVE-2021-27365        0
# 2023-02-08 10:00:00+00:00  CVE-2021-27365        0
# 2023-02-08 10:00:00+00:00  CVE-2021-27365        0
# 2023-02-08 12:00:00+00:00  CVE-2021-27365        0
# 2023-02-08 14:00:00+00:00  CVE-2021-27365        0
#
# [113 rows x 2 columns]

# %%
df_test['CVE'].iloc[0]
# Out:
# 'CVE-2021-27365'

# %%
df_test.rename(columns = {'CVE':df_test['CVE'].iloc[0]}, inplace = True)

# %%
df_test
# Out:
#                            CVE-2021-27365  flag_CR
# rd_created_at
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0
# ...                                   ...      ...
# 2023-02-08 08:00:00+00:00  CVE-2021-27365        0
# 2023-02-08 10:00:00+00:00  CVE-2021-27365        0
# 2023-02-08 10:00:00+00:00  CVE-2021-27365        0
# 2023-02-08 12:00:00+00:00  CVE-2021-27365        0
# 2023-02-08 14:00:00+00:00  CVE-2021-27365        0
#
# [113 rows x 2 columns]

# %%
df_test['count'] = df_test.groupby(['rd_created_at'])[df_test.columns[0]].count()
df_test
# Out:
#                            CVE-2021-27365  flag_CR  count
# rd_created_at
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0     18
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0     18
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0     18
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0     18
# 2023-02-06 15:00:00+00:00  CVE-2021-27365        0     18
# ...                                   ...      ...    ...
# 2023-02-08 08:00:00+00:00  CVE-2021-27365        0      2
# 2023-02-08 10:00:00+00:00  CVE-2021-27365        0      2
# 2023-02-08 10:00:00+00:00  CVE-2021-27365        0      2
# 2023-02-08 12:00:00+00:00  CVE-2021-27365        0      1
# 2023-02-08 14:00:00+00:00  CVE-2021-27365        0      1
#
# [113 rows x 3 columns]

# %%
y = df_test[[df_test.columns[1]]]
y
# Out:
#                            flag_CR
# rd_created_at
# 2023-02-06 15:00:00+00:00        0
# 2023-02-06 15:00:00+00:00        0
# 2023-02-06 15:00:00+00:00        0
# 2023-02-06 15:00:00+00:00        0
# 2023-02-06 15:00:00+00:00        0
# ...                            ...
# 2023-02-08 08:00:00+00:00        0
# 2023-02-08 10:00:00+00:00        0
# 2023-02-08 10:00:00+00:00        0
# 2023-02-08 12:00:00+00:00        0
# 2023-02-08 14:00:00+00:00        0
#
# [113 rows x 1 columns]

# %%
df_test_counted = df_test.drop([df_test.columns[1]], axis = 'columns')
df_test_counted
# Out:
#                            CVE-2021-27365  count
# rd_created_at
# 2023-02-06 15:00:00+00:00  CVE-2021-27365     18
# 2023-02-06 15:00:00+00:00  CVE-2021-27365     18
# 2023-02-06 15:00:00+00:00  CVE-2021-27365     18
# 2023-02-06 15:00:00+00:00  CVE-2021-27365     18
# 2023-02-06 15:00:00+00:00  CVE-2021-27365     18
# ...                                   ...    ...
# 2023-02-08 08:00:00+00:00  CVE-2021-27365      2
# 2023-02-08 10:00:00+00:00  CVE-2021-27365      2
# 2023-02-08 10:00:00+00:00  CVE-2021-27365      2
# 2023-02-08 12:00:00+00:00  CVE-2021-27365      1
# 2023-02-08 14:00:00+00:00  CVE-2021-27365      1
#
# [113 rows x 2 columns]

# %%
from tsfresh import extract_features, extract_relevant_features
df_test_features = extract_relevant_features(df_test_counted,y,column_id = 'CVE-2021-27365')
df_test_features.head(0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[86], line 2
#       1 from tsfresh import extract_features, extract_relevant_features
# ----> 2 df_test_features = extract_relevant_features(df_test_counted,y,column_id = 'CVE-2021-27365')
#       3 df_test_features.head(0)
#
# File /opt/conda/lib/python3.10/site-packages/tsfresh/convenience/relevant_extraction.py:156, in extract_relevant_features(timeseries_container, y, X, default_fc_parameters, kind_to_fc_parameters, column_id, column_sort, column_kind, column_value, show_warnings, disable_progressbar, profile, profiling_filename, profiling_sorting, test_for_binary_target_binary_feature, test_for_binary_target_real_feature, test_for_real_target_binary_feature, test_for_real_target_real_feature, fdr_level, hypotheses_independent, n_jobs, distributor, chunksize, ml_task)
#      17 def extract_relevant_features(
# ...
