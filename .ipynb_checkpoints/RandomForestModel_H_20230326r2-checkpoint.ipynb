# %%
# Read the csv files
import pandas as pd
import datetime
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
df_features = pd.read_csv("1677CVEs_783dim_features_20230326.csv")
df_features
# Out:
#           Unnamed: 0  count__variance_larger_than_standard_deviation  \
# 0     CVE-2006-10001                                             1.0
# 1     CVE-2008-10002                                             0.0
# 2     CVE-2008-10003                                             1.0
# 3     CVE-2008-10004                                             1.0
# 4     CVE-2011-10002                                             1.0
# ...              ...                                             ...
# 1672  CVE-2023-28685                                             0.0
# 1673  CVE-2023-28686                                             1.0
# 1674  CVE-2023-28708                                             1.0
# 1675  CVE-2023-28725                                             1.0
# 1676  CVE-2023-28818                                             1.0
#
#       count__has_duplicate_max  count__has_duplicate_min  \
# 0                          0.0                       1.0
# 1                          1.0                       1.0
# 2                          0.0                       1.0
# 3                          0.0                       1.0
# 4                          0.0                       1.0
# ...                        ...                       ...
# 1672                       0.0                       1.0
# 1673                       1.0                       1.0
# 1674                       0.0                       1.0
# 1675                       0.0                       0.0
# 1676                       1.0                       0.0
#
#       count__has_duplicate  count__sum_values  count__abs_energy  \
# 0                      1.0               16.0               60.0
# 1                      1.0               15.0               37.0
# 2                      1.0               16.0               44.0
# 3                      1.0               20.0              110.0
# 4                      1.0               12.0               54.0
# ...                    ...                ...                ...
# 1672                   1.0               15.0               35.0
# 1673                   1.0               15.0               43.0
# 1674                   1.0               30.0              100.0
# 1675                   1.0               15.0               61.0
# 1676                   1.0               13.0               41.0
#
#       count__mean_abs_change  count__mean_change  \
# 0                   2.000000           -0.400000
# 1                   1.333333           -0.333333
# 2                   1.000000           -0.333333
# 3                   4.000000           -0.333333
# 4                   2.333333           -1.000000
# ...                      ...                 ...
# 1672                1.285714           -0.142857
# 1673                1.666667            0.000000
# 1674                1.692308           -0.153846
# 1675                2.250000           -0.250000
# 1676                2.250000           -0.250000
#
#       count__mean_second_derivative_central  ...  \
# 0                                  0.125000  ...
# 1                                  0.100000  ...
# 2                                 -0.100000  ...
# 3                                  0.200000  ...
# 4                                 -0.500000  ...
# ...                                     ...  ...
# 1672                               0.000000  ...
# 1673                              -0.100000  ...
# 1674                              -0.125000  ...
# 1675                              -0.500000  ...
# 1676                              -0.833333  ...
#
#       count__fourier_entropy__bins_5  count__fourier_entropy__bins_10  \
# 0                           1.039721                         1.039721
# 1                           1.039721                         1.039721
# 2                           1.386294                         1.386294
# 3                           1.039721                         1.386294
# 4                           1.098612                         1.098612
# ...                              ...                              ...
# 1672                        1.332179                         1.332179
# 1673                        1.039721                         1.039721
# 1674                        1.494175                         1.732868
# 1675                        1.098612                         1.098612
# 1676                        0.636514                         0.636514
#
#       count__fourier_entropy__bins_100  \
# 0                             1.386294
# 1                             1.039721
# 2                             1.386294
# 3                             1.386294
# 4                             1.098612
# ...                                ...
# 1672                          1.609438
# 1673                          1.386294
# 1674                          1.906155
# 1675                          1.098612
# 1676                          1.098612
#
#       count__permutation_entropy__dimension_3__tau_1  \
# 0                                           1.386294
# 1                                           1.054920
# 2                                           1.332179
# 3                                           1.054920
# 4                                           0.693147
# ...                                              ...
# 1672                                        1.329661
# 1673                                        1.609438
# 1674                                        1.329661
# 1675                                        1.098612
# 1676                                        1.098612
#
#       count__permutation_entropy__dimension_4__tau_1  \
# 0                                           1.098612
# 1                                           1.039721
# 2                                           1.386294
# 3                                           1.039721
# 4                                          -0.000000
# ...                                              ...
# 1672                                        1.609438
# 1673                                        1.386294
# 1674                                        1.893788
# 1675                                        0.693147
# 1676                                        0.693147
#
#       count__permutation_entropy__dimension_5__tau_1  \
# 0                                           0.693147
# 1                                           1.098612
# 2                                           1.098612
# 3                                           1.098612
# 4                                                NaN
# ...                                              ...
# 1672                                        1.386294
# 1673                                        1.098612
# 1674                                        2.302585
# 1675                                       -0.000000
# 1676                                       -0.000000
#
#       count__permutation_entropy__dimension_6__tau_1  \
# 0                                          -0.000000
# 1                                           0.693147
# 2                                           0.693147
# 3                                           0.693147
# 4                                                NaN
# ...                                              ...
# 1672                                        1.098612
# 1673                                        0.693147
# 1674                                        2.197225
# 1675                                             NaN
# 1676                                             NaN
#
#       count__permutation_entropy__dimension_7__tau_1  \
# 0                                                NaN
# 1                                          -0.000000
# 2                                          -0.000000
# 3                                          -0.000000
# 4                                                NaN
# ...                                              ...
# 1672                                        0.693147
# 1673                                       -0.000000
# 1674                                        2.079442
# 1675                                             NaN
# 1676                                             NaN
#
#       count__query_similarity_count__query_None__threshold_0.0  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1672                                                NaN
# 1673                                                NaN
# 1674                                                NaN
# 1675                                                NaN
# 1676                                                NaN
#
#       count__mean_n_absolute_max__number_of_maxima_7
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 1672                                        2.000000
# 1673                                             NaN
# 1674                                        3.285714
# 1675                                             NaN
# 1676                                             NaN
#
# [1677 rows x 784 columns]

# %%
df_flag = pd.read_csv("CVE_list_with_flagH_20230326.csv", index_col = ['CVE'] )
df_flag_sorted = df_flag.sort_values('CVE')
df_flag_sorted
# Out:
#                 Unnamed: 0  flag_H
# CVE
# CVE-2006-10001         344       0
# CVE-2008-10002         591       0
# CVE-2008-10003         446       1
# CVE-2008-10004         173       1
# CVE-2011-10002         318       1
# ...                    ...     ...
# CVE-2023-28685         558       1
# CVE-2023-28686         840       1
# CVE-2023-28708         115       0
# CVE-2023-28725         962       1
# CVE-2023-28818        1665       0
#
# [1677 rows x 2 columns]

# %%
df_flag_sorted.drop('Unnamed: 0', inplace = True, axis = 1)

# %%
df_flag_sorted
# Out:
#                 flag_H
# CVE
# CVE-2006-10001       0
# CVE-2008-10002       0
# CVE-2008-10003       1
# CVE-2008-10004       1
# CVE-2011-10002       1
# ...                ...
# CVE-2023-28685       1
# CVE-2023-28686       1
# CVE-2023-28708       0
# CVE-2023-28725       1
# CVE-2023-28818       0
#
# [1677 rows x 1 columns]

# %%
df_features.rename({"Unnamed: 0" : "CVE"}, inplace = True, axis = 1)
df_features
# Out:
#                  CVE  count__variance_larger_than_standard_deviation  \
# 0     CVE-2006-10001                                             1.0
# 1     CVE-2008-10002                                             0.0
# 2     CVE-2008-10003                                             1.0
# 3     CVE-2008-10004                                             1.0
# 4     CVE-2011-10002                                             1.0
# ...              ...                                             ...
# 1672  CVE-2023-28685                                             0.0
# 1673  CVE-2023-28686                                             1.0
# 1674  CVE-2023-28708                                             1.0
# 1675  CVE-2023-28725                                             1.0
# 1676  CVE-2023-28818                                             1.0
#
#       count__has_duplicate_max  count__has_duplicate_min  \
# 0                          0.0                       1.0
# 1                          1.0                       1.0
# 2                          0.0                       1.0
# 3                          0.0                       1.0
# 4                          0.0                       1.0
# ...                        ...                       ...
# 1672                       0.0                       1.0
# 1673                       1.0                       1.0
# 1674                       0.0                       1.0
# 1675                       0.0                       0.0
# 1676                       1.0                       0.0
#
#       count__has_duplicate  count__sum_values  count__abs_energy  \
# 0                      1.0               16.0               60.0
# 1                      1.0               15.0               37.0
# 2                      1.0               16.0               44.0
# 3                      1.0               20.0              110.0
# 4                      1.0               12.0               54.0
# ...                    ...                ...                ...
# 1672                   1.0               15.0               35.0
# 1673                   1.0               15.0               43.0
# 1674                   1.0               30.0              100.0
# 1675                   1.0               15.0               61.0
# 1676                   1.0               13.0               41.0
#
#       count__mean_abs_change  count__mean_change  \
# 0                   2.000000           -0.400000
# 1                   1.333333           -0.333333
# 2                   1.000000           -0.333333
# 3                   4.000000           -0.333333
# 4                   2.333333           -1.000000
# ...                      ...                 ...
# 1672                1.285714           -0.142857
# 1673                1.666667            0.000000
# 1674                1.692308           -0.153846
# 1675                2.250000           -0.250000
# 1676                2.250000           -0.250000
#
#       count__mean_second_derivative_central  ...  \
# 0                                  0.125000  ...
# 1                                  0.100000  ...
# 2                                 -0.100000  ...
# 3                                  0.200000  ...
# 4                                 -0.500000  ...
# ...                                     ...  ...
# 1672                               0.000000  ...
# 1673                              -0.100000  ...
# 1674                              -0.125000  ...
# 1675                              -0.500000  ...
# 1676                              -0.833333  ...
#
#       count__fourier_entropy__bins_5  count__fourier_entropy__bins_10  \
# 0                           1.039721                         1.039721
# 1                           1.039721                         1.039721
# 2                           1.386294                         1.386294
# 3                           1.039721                         1.386294
# 4                           1.098612                         1.098612
# ...                              ...                              ...
# 1672                        1.332179                         1.332179
# 1673                        1.039721                         1.039721
# 1674                        1.494175                         1.732868
# 1675                        1.098612                         1.098612
# 1676                        0.636514                         0.636514
#
#       count__fourier_entropy__bins_100  \
# 0                             1.386294
# 1                             1.039721
# 2                             1.386294
# 3                             1.386294
# 4                             1.098612
# ...                                ...
# 1672                          1.609438
# 1673                          1.386294
# 1674                          1.906155
# 1675                          1.098612
# 1676                          1.098612
#
#       count__permutation_entropy__dimension_3__tau_1  \
# 0                                           1.386294
# 1                                           1.054920
# 2                                           1.332179
# 3                                           1.054920
# 4                                           0.693147
# ...                                              ...
# 1672                                        1.329661
# 1673                                        1.609438
# 1674                                        1.329661
# 1675                                        1.098612
# 1676                                        1.098612
#
#       count__permutation_entropy__dimension_4__tau_1  \
# 0                                           1.098612
# 1                                           1.039721
# 2                                           1.386294
# 3                                           1.039721
# 4                                          -0.000000
# ...                                              ...
# 1672                                        1.609438
# 1673                                        1.386294
# 1674                                        1.893788
# 1675                                        0.693147
# 1676                                        0.693147
#
#       count__permutation_entropy__dimension_5__tau_1  \
# 0                                           0.693147
# 1                                           1.098612
# 2                                           1.098612
# 3                                           1.098612
# 4                                                NaN
# ...                                              ...
# 1672                                        1.386294
# 1673                                        1.098612
# 1674                                        2.302585
# 1675                                       -0.000000
# 1676                                       -0.000000
#
#       count__permutation_entropy__dimension_6__tau_1  \
# 0                                          -0.000000
# 1                                           0.693147
# 2                                           0.693147
# 3                                           0.693147
# 4                                                NaN
# ...                                              ...
# 1672                                        1.098612
# 1673                                        0.693147
# 1674                                        2.197225
# 1675                                             NaN
# 1676                                             NaN
#
#       count__permutation_entropy__dimension_7__tau_1  \
# 0                                                NaN
# 1                                          -0.000000
# 2                                          -0.000000
# 3                                          -0.000000
# 4                                                NaN
# ...                                              ...
# 1672                                        0.693147
# 1673                                       -0.000000
# 1674                                        2.079442
# 1675                                             NaN
# 1676                                             NaN
#
#       count__query_similarity_count__query_None__threshold_0.0  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1672                                                NaN
# 1673                                                NaN
# 1674                                                NaN
# 1675                                                NaN
# 1676                                                NaN
#
#       count__mean_n_absolute_max__number_of_maxima_7
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 1672                                        2.000000
# 1673                                             NaN
# 1674                                        3.285714
# 1675                                             NaN
# 1676                                             NaN
#
# [1677 rows x 784 columns]

# %%
df_features.set_index('CVE', inplace = True)
df_features
# Out:
#                 count__variance_larger_than_standard_deviation  \
# CVE
# CVE-2006-10001                                             1.0
# CVE-2008-10002                                             0.0
# CVE-2008-10003                                             1.0
# CVE-2008-10004                                             1.0
# CVE-2011-10002                                             1.0
# ...                                                        ...
# CVE-2023-28685                                             0.0
# CVE-2023-28686                                             1.0
# CVE-2023-28708                                             1.0
# CVE-2023-28725                                             1.0
# CVE-2023-28818                                             1.0
#
#                 count__has_duplicate_max  count__has_duplicate_min  \
# CVE
# CVE-2006-10001                       0.0                       1.0
# CVE-2008-10002                       1.0                       1.0
# CVE-2008-10003                       0.0                       1.0
# CVE-2008-10004                       0.0                       1.0
# CVE-2011-10002                       0.0                       1.0
# ...                                  ...                       ...
# CVE-2023-28685                       0.0                       1.0
# CVE-2023-28686                       1.0                       1.0
# CVE-2023-28708                       0.0                       1.0
# CVE-2023-28725                       0.0                       0.0
# CVE-2023-28818                       1.0                       0.0
#
#                 count__has_duplicate  count__sum_values  count__abs_energy  \
# CVE
# CVE-2006-10001                   1.0               16.0               60.0
# CVE-2008-10002                   1.0               15.0               37.0
# CVE-2008-10003                   1.0               16.0               44.0
# CVE-2008-10004                   1.0               20.0              110.0
# CVE-2011-10002                   1.0               12.0               54.0
# ...                              ...                ...                ...
# CVE-2023-28685                   1.0               15.0               35.0
# CVE-2023-28686                   1.0               15.0               43.0
# CVE-2023-28708                   1.0               30.0              100.0
# CVE-2023-28725                   1.0               15.0               61.0
# CVE-2023-28818                   1.0               13.0               41.0
#
#                 count__mean_abs_change  count__mean_change  \
# CVE
# CVE-2006-10001                2.000000           -0.400000
# CVE-2008-10002                1.333333           -0.333333
# CVE-2008-10003                1.000000           -0.333333
# CVE-2008-10004                4.000000           -0.333333
# CVE-2011-10002                2.333333           -1.000000
# ...                                ...                 ...
# CVE-2023-28685                1.285714           -0.142857
# CVE-2023-28686                1.666667            0.000000
# CVE-2023-28708                1.692308           -0.153846
# CVE-2023-28725                2.250000           -0.250000
# CVE-2023-28818                2.250000           -0.250000
#
#                 count__mean_second_derivative_central  count__median  ...  \
# CVE                                                                   ...
# CVE-2006-10001                               0.125000            2.5  ...
# CVE-2008-10002                               0.100000            2.0  ...
# CVE-2008-10003                              -0.100000            2.0  ...
# CVE-2008-10004                               0.200000            1.0  ...
# CVE-2011-10002                              -0.500000            2.5  ...
# ...                                               ...            ...  ...
# CVE-2023-28685                               0.000000            2.0  ...
# CVE-2023-28686                              -0.100000            2.0  ...
# CVE-2023-28708                              -0.125000            1.0  ...
# CVE-2023-28725                              -0.500000            2.0  ...
# CVE-2023-28818                              -0.833333            2.0  ...
#
#                 count__fourier_entropy__bins_5  \
# CVE
# CVE-2006-10001                        1.039721
# CVE-2008-10002                        1.039721
# CVE-2008-10003                        1.386294
# CVE-2008-10004                        1.039721
# CVE-2011-10002                        1.098612
# ...                                        ...
# CVE-2023-28685                        1.332179
# CVE-2023-28686                        1.039721
# CVE-2023-28708                        1.494175
# CVE-2023-28725                        1.098612
# CVE-2023-28818                        0.636514
#
#                 count__fourier_entropy__bins_10  \
# CVE
# CVE-2006-10001                         1.039721
# CVE-2008-10002                         1.039721
# CVE-2008-10003                         1.386294
# CVE-2008-10004                         1.386294
# CVE-2011-10002                         1.098612
# ...                                         ...
# CVE-2023-28685                         1.332179
# CVE-2023-28686                         1.039721
# CVE-2023-28708                         1.732868
# CVE-2023-28725                         1.098612
# CVE-2023-28818                         0.636514
#
#                 count__fourier_entropy__bins_100  \
# CVE
# CVE-2006-10001                          1.386294
# CVE-2008-10002                          1.039721
# CVE-2008-10003                          1.386294
# CVE-2008-10004                          1.386294
# CVE-2011-10002                          1.098612
# ...                                          ...
# CVE-2023-28685                          1.609438
# CVE-2023-28686                          1.386294
# CVE-2023-28708                          1.906155
# CVE-2023-28725                          1.098612
# CVE-2023-28818                          1.098612
#
#                 count__permutation_entropy__dimension_3__tau_1  \
# CVE
# CVE-2006-10001                                        1.386294
# CVE-2008-10002                                        1.054920
# CVE-2008-10003                                        1.332179
# CVE-2008-10004                                        1.054920
# CVE-2011-10002                                        0.693147
# ...                                                        ...
# CVE-2023-28685                                        1.329661
# CVE-2023-28686                                        1.609438
# CVE-2023-28708                                        1.329661
# CVE-2023-28725                                        1.098612
# CVE-2023-28818                                        1.098612
#
#                 count__permutation_entropy__dimension_4__tau_1  \
# CVE
# CVE-2006-10001                                        1.098612
# CVE-2008-10002                                        1.039721
# CVE-2008-10003                                        1.386294
# CVE-2008-10004                                        1.039721
# CVE-2011-10002                                       -0.000000
# ...                                                        ...
# CVE-2023-28685                                        1.609438
# CVE-2023-28686                                        1.386294
# CVE-2023-28708                                        1.893788
# CVE-2023-28725                                        0.693147
# CVE-2023-28818                                        0.693147
#
#                 count__permutation_entropy__dimension_5__tau_1  \
# CVE
# CVE-2006-10001                                        0.693147
# CVE-2008-10002                                        1.098612
# CVE-2008-10003                                        1.098612
# CVE-2008-10004                                        1.098612
# CVE-2011-10002                                             NaN
# ...                                                        ...
# CVE-2023-28685                                        1.386294
# CVE-2023-28686                                        1.098612
# CVE-2023-28708                                        2.302585
# CVE-2023-28725                                       -0.000000
# CVE-2023-28818                                       -0.000000
#
#                 count__permutation_entropy__dimension_6__tau_1  \
# CVE
# CVE-2006-10001                                       -0.000000
# CVE-2008-10002                                        0.693147
# CVE-2008-10003                                        0.693147
# CVE-2008-10004                                        0.693147
# CVE-2011-10002                                             NaN
# ...                                                        ...
# CVE-2023-28685                                        1.098612
# CVE-2023-28686                                        0.693147
# CVE-2023-28708                                        2.197225
# CVE-2023-28725                                             NaN
# CVE-2023-28818                                             NaN
#
#                 count__permutation_entropy__dimension_7__tau_1  \
# CVE
# CVE-2006-10001                                             NaN
# CVE-2008-10002                                       -0.000000
# CVE-2008-10003                                       -0.000000
# CVE-2008-10004                                       -0.000000
# CVE-2011-10002                                             NaN
# ...                                                        ...
# CVE-2023-28685                                        0.693147
# CVE-2023-28686                                       -0.000000
# CVE-2023-28708                                        2.079442
# CVE-2023-28725                                             NaN
# CVE-2023-28818                                             NaN
#
#                 count__query_similarity_count__query_None__threshold_0.0  \
# CVE
# CVE-2006-10001                                                NaN
# CVE-2008-10002                                                NaN
# CVE-2008-10003                                                NaN
# CVE-2008-10004                                                NaN
# CVE-2011-10002                                                NaN
# ...                                                           ...
# CVE-2023-28685                                                NaN
# CVE-2023-28686                                                NaN
# CVE-2023-28708                                                NaN
# CVE-2023-28725                                                NaN
# CVE-2023-28818                                                NaN
#
#                 count__mean_n_absolute_max__number_of_maxima_7
# CVE
# CVE-2006-10001                                             NaN
# CVE-2008-10002                                             NaN
# CVE-2008-10003                                             NaN
# CVE-2008-10004                                             NaN
# CVE-2011-10002                                             NaN
# ...                                                        ...
# CVE-2023-28685                                        2.000000
# CVE-2023-28686                                             NaN
# CVE-2023-28708                                        3.285714
# CVE-2023-28725                                             NaN
# CVE-2023-28818                                             NaN
#
# [1677 rows x 783 columns]

# %% [markdown]
# ## Dividing Data

# %%
df_features.isnull().sum()
# Out:
# count__variance_larger_than_standard_deviation                 0
# count__has_duplicate_max                                       0
# count__has_duplicate_min                                       0
# count__has_duplicate                                           0
# count__sum_values                                              0
#                                                             ...
# count__permutation_entropy__dimension_5__tau_1               452
# count__permutation_entropy__dimension_6__tau_1               790
# count__permutation_entropy__dimension_7__tau_1              1105
# count__query_similarity_count__query_None__threshold_0.0    1677
# count__mean_n_absolute_max__number_of_maxima_7              1355
# Length: 783, dtype: int64

# %% [markdown]
# ## Filter the features which are NaN

# %%
# !pip3 install tsfresh
# Out:
# Collecting tsfresh
#   Downloading tsfresh-0.20.0-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.10.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from tsfresh) (4.64.1)
# Requirement already satisfied: pandas>=0.25.0 in /home/kimura/.local/lib/python3.10/site-packages (from tsfresh) (2.0.2)
# Requirement already satisfied: dask[dataframe]>=2.9.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from tsfresh) (2022.7.0)
# Requirement already satisfied: numpy>=1.15.1 in /home/kimura/anaconda3/lib/python3.10/site-packages (from tsfresh) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from tsfresh) (1.10.0)
# Requirement already satisfied: requests>=2.9.1 in /home/kimura/.local/lib/python3.10/site-packages (from tsfresh) (2.31.0)
# Requirement already satisfied: statsmodels>=0.13 in /home/kimura/anaconda3/lib/python3.10/site-packages (from tsfresh) (0.13.5)
# Requirement already satisfied: distributed>=2.11.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from tsfresh) (2022.7.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from tsfresh) (1.2.1)
# Collecting stumpy>=1.7.2
#   Downloading stumpy-1.11.1-py3-none-any.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.2/136.2 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle in /home/kimura/anaconda3/lib/python3.10/site-packages (from tsfresh) (2.0.0)
# Requirement already satisfied: patsy>=0.4.1 in /home/kimura/anaconda3/lib/python3.10/site-packages (from tsfresh) (0.5.3)
# Requirement already satisfied: partd>=0.3.10 in /home/kimura/anaconda3/lib/python3.10/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (1.2.0)
# Requirement already satisfied: fsspec>=0.6.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (2022.11.0)
# Requirement already satisfied: toolz>=0.8.2 in /home/kimura/anaconda3/lib/python3.10/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (0.12.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/kimura/anaconda3/lib/python3.10/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (6.0)
# Requirement already satisfied: packaging>=20.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (22.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /home/kimura/anaconda3/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (2.4.0)
# Requirement already satisfied: psutil>=5.0 in /home/kimura/.local/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (5.9.5)
# Requirement already satisfied: urllib3 in /home/kimura/anaconda3/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (1.26.14)
# Requirement already satisfied: jinja2 in /home/kimura/anaconda3/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (3.1.2)
# Collecting tornado<6.2,>=6.0.3
#   Downloading tornado-6.1.tar.gz (497 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.4/497.4 kB 10.5 MB/s eta 0:00:0031m10.0 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click>=6.6 in /home/kimura/anaconda3/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (8.0.4)
# Requirement already satisfied: tblib>=1.6.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (1.7.0)
# Requirement already satisfied: msgpack>=0.6.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (1.0.3)
# Requirement already satisfied: locket>=1.0.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (1.0.0)
# Requirement already satisfied: zict>=0.1.3 in /home/kimura/anaconda3/lib/python3.10/site-packages (from distributed>=2.11.0->tsfresh) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kimura/.local/lib/python3.10/site-packages (from pandas>=0.25.0->tsfresh) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/kimura/.local/lib/python3.10/site-packages (from pandas>=0.25.0->tsfresh) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/kimura/anaconda3/lib/python3.10/site-packages (from pandas>=0.25.0->tsfresh) (2022.7)
# Requirement already satisfied: six in /home/kimura/anaconda3/lib/python3.10/site-packages (from patsy>=0.4.1->tsfresh) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/kimura/anaconda3/lib/python3.10/site-packages (from requests>=2.9.1->tsfresh) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kimura/anaconda3/lib/python3.10/site-packages (from requests>=2.9.1->tsfresh) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/kimura/.local/lib/python3.10/site-packages (from requests>=2.9.1->tsfresh) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/kimura/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.22.0->tsfresh) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.22.0->tsfresh) (2.2.0)
# Requirement already satisfied: numba>=0.54 in /home/kimura/anaconda3/lib/python3.10/site-packages (from stumpy>=1.7.2->tsfresh) (0.56.4)
# Requirement already satisfied: setuptools in /home/kimura/anaconda3/lib/python3.10/site-packages (from numba>=0.54->stumpy>=1.7.2->tsfresh) (65.6.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from numba>=0.54->stumpy>=1.7.2->tsfresh) (0.39.1)
# Requirement already satisfied: heapdict in /home/kimura/anaconda3/lib/python3.10/site-packages (from zict>=0.1.3->distributed>=2.11.0->tsfresh) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kimura/anaconda3/lib/python3.10/site-packages (from jinja2->distributed>=2.11.0->tsfresh) (2.1.1)
# Building wheels for collected packages: tornado
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-6.1-cp310-cp310-linux_x86_64.whl size=417223 sha256=da7deb167d22710ecc986242891e717c998e4957aba342d5a51841edc858738b
#   Stored in directory: /home/kimura/.cache/pip/wheels/34/83/69/b89863a68e62add6e149dbaadcc049886105ce2405c1979bf2
# Successfully built tornado
# Installing collected packages: tornado, stumpy, tsfresh
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.3.2
#     Uninstalling tornado-6.3.2:
#       Successfully uninstalled tornado-6.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab 4.0.0 requires tornado>=6.2.0, but you have tornado 6.1 which is incompatible.
# jupyter-server 2.6.0 requires tornado>=6.2.0, but you have tornado 6.1 which is incompatible.
# jupyter-client 8.2.0 requires tornado>=6.2, but you have tornado 6.1 which is incompatible.
# spyder-kernels 2.4.1 requires jupyter-client<8,>=7.3.4; python_version >= "3", but you have jupyter-client 8.2.0 which is incompatible.
# Successfully installed stumpy-1.11.1 tornado-6.1 tsfresh-0.20.0

# %%
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute
impute(df_features)
# y = df_flag_sorted['flag_H']
# features_filterd = select_features(df_features, y)
# features_filterd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from tsfresh import select_features
#       2 from tsfresh.utilities.dataframe_functions import impute
#       3 impute(df_features)
#
# File ~/anaconda3/lib/python3.10/site-packages/tsfresh/__init__.py:27
#      22 from logging import NullHandler
#      24 logging.getLogger(__name__).addHandler(NullHandler())
# ---> 27 from tsfresh.convenience.relevant_extraction import (  # noqa: E402
#      28     extract_relevant_features,
#      29 )
#      30 from tsfresh.feature_extraction import extract_features  # noqa: E402
#      31 from tsfresh.feature_selection import select_features
#
# File ~/anaconda3/lib/python3.10/site-packages/tsfresh/convenience/relevant_extraction.py:8
#       5 import pandas as pd
#       7 from tsfresh import defaults
# ----> 8 from tsfresh.feature_extraction import extract_features
#       9 from tsfresh.feature_selection import select_features
#      10 from tsfresh.utilities.dataframe_functions import (
#      11     get_ids,
#      12     impute,
#      13     restrict_input_to_index,
#      14 )
#
# File ~/anaconda3/lib/python3.10/site-packages/tsfresh/feature_extraction/__init__.py:5
#       1 """
#       2 The :mod:`tsfresh.feature_extraction` module contains methods to extract the features from the time series
#       3 """
# ----> 5 from tsfresh.feature_extraction.extraction import extract_features
#       6 from tsfresh.feature_extraction.settings import (
#       7     ComprehensiveFCParameters,
#       8     EfficientFCParameters,
#       9     MinimalFCParameters,
#      10 )
#
# File ~/anaconda3/lib/python3.10/site-packages/tsfresh/feature_extraction/extraction.py:16
#      14 from tsfresh import defaults
#      15 from tsfresh.feature_extraction import feature_calculators
# ---> 16 from tsfresh.feature_extraction.data import to_tsdata
#      17 from tsfresh.feature_extraction.settings import ComprehensiveFCParameters
#      18 from tsfresh.utilities import profiling
#
# File ~/anaconda3/lib/python3.10/site-packages/tsfresh/feature_extraction/data.py:8
#       5 import pandas as pd
#       7 try:
# ----> 8     from dask import dataframe as dd
#       9 except ImportError:  # pragma: no cover
#      10     dd = None
#
# File ~/anaconda3/lib/python3.10/site-packages/dask/dataframe/__init__.py:4
#       2 import dask.dataframe._pyarrow_compat
#       3 from dask.base import compute
# ----> 4 from dask.dataframe import backends, dispatch, rolling
#       5 from dask.dataframe.core import (
#       6     DataFrame,
#       7     Index,
#    (...)
#      13     to_timedelta,
#      14 )
#      15 from dask.dataframe.groupby import Aggregation
#
# File ~/anaconda3/lib/python3.10/site-packages/dask/dataframe/backends.py:20
#      18 from dask.array.dispatch import percentile_lookup
#      19 from dask.array.percentile import _percentile
# ---> 20 from dask.dataframe.core import DataFrame, Index, Scalar, Series, _Frame
#      21 from dask.dataframe.dispatch import (
#      22     categorical_dtype_dispatch,
#      23     concat,
#    (...)
#      35     union_categoricals_dispatch,
#      36 )
#      37 from dask.dataframe.extensions import make_array_nonempty, make_scalar
#
# File ~/anaconda3/lib/python3.10/site-packages/dask/dataframe/core.py:35
#      33 from dask.blockwise import Blockwise, BlockwiseDep, BlockwiseDepDict, blockwise
#      34 from dask.context import globalmethod
# ---> 35 from dask.dataframe import methods
#      36 from dask.dataframe._compat import PANDAS_GT_140, PANDAS_GT_150
#      37 from dask.dataframe.accessor import CachedAccessor, DatetimeAccessor, StringAccessor
#
# File ~/anaconda3/lib/python3.10/site-packages/dask/dataframe/methods.py:22
#      10 #  preserve compatibility while moving dispatch objects
#      11 from dask.dataframe.dispatch import (  # noqa: F401
#      12     concat,
#      13     concat_dispatch,
#    (...)
#      20     union_categoricals,
#      21 )
# ---> 22 from dask.dataframe.utils import is_dataframe_like, is_index_like, is_series_like
#      24 # cuDF may try to import old dispatch functions
#      25 hash_df = hash_object_dispatch
#
# File ~/anaconda3/lib/python3.10/site-packages/dask/dataframe/utils.py:18
#      16 from dask.base import get_scheduler, is_dask_collection
#      17 from dask.core import get_deps
# ---> 18 from dask.dataframe import (  # noqa: F401 register pandas extension types
#      19     _dtypes,
#      20     methods,
#      21 )
#      22 from dask.dataframe._compat import PANDAS_GT_110, PANDAS_GT_120, tm  # noqa: F401
#      23 from dask.dataframe.dispatch import (  # noqa : F401
#      24     make_meta,
#      25     make_meta_obj,
#      26     meta_nonempty,
#      27 )
#
# File ~/anaconda3/lib/python3.10/site-packages/dask/dataframe/_dtypes.py:3
#       1 import pandas as pd
# ----> 3 from dask.dataframe.extensions import make_array_nonempty, make_scalar
#       6 @make_array_nonempty.register(pd.DatetimeTZDtype)
#       7 def _(dtype):
#       8     return pd.array([pd.Timestamp(1), pd.NaT], dtype=dtype)
#
# File ~/anaconda3/lib/python3.10/site-packages/dask/dataframe/extensions.py:6
#       1 """
#       2 Support for pandas ExtensionArray in dask.dataframe.
#       3
#       4 See :ref:`extensionarrays` for more.
#       5 """
# ----> 6 from dask.dataframe.accessor import (
#       7     register_dataframe_accessor,
#       8     register_index_accessor,
#       9     register_series_accessor,
#      10 )
#      11 from dask.utils import Dispatch
#      13 make_array_nonempty = Dispatch("make_array_nonempty")
#
# File ~/anaconda3/lib/python3.10/site-packages/dask/dataframe/accessor.py:190
#     129     _accessor_methods = (
#     130         "asfreq",
#     131         "ceil",
#    (...)
#     145         "tz_localize",
#     146     )
#     148     _accessor_properties = (
#     149         "components",
#     150         "date",
#    (...)
#     186         "year",
#     187     )
# --> 190 class StringAccessor(Accessor):
#     191     """Accessor object for string properties of the Series values.
#     192
#     193     Examples
#    (...)
#     196     >>> s.str.lower()  # doctest: +SKIP
#     197     """
#     199     _accessor_name = "str"
#
# File ~/anaconda3/lib/python3.10/site-packages/dask/dataframe/accessor.py:276, in StringAccessor()
#     272         meta = (self._series.name, object)
#     273     return self._function_map(method, pat=pat, n=n, expand=expand, meta=meta)
#     275 @derived_from(
# --> 276     pd.core.strings.StringMethods,
#     277     inconsistencies="``expand=True`` with unknown ``n`` will raise a ``NotImplementedError``",
#     278 )
#     279 def split(self, pat=None, n=-1, expand=False):
#     280     """Known inconsistencies: ``expand=True`` with unknown ``n`` will raise a ``NotImplementedError``."""
#     281     return self._split("split", pat=pat, n=n, expand=expand)
#
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'

# %% [markdown]
# ## Random Forest (No Cross Validation)

# %%
train_data = df_features
y = df_flag_sorted['flag_H']
X = train_data.values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1234)

# %%
clf = RandomForestClassifier(random_state = 1234)
clf.fit(X_train, y_train)
print(f"accuracy={clf.score(X_test, y_test)}")

# %%
y_predict = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
print(f"comfusion_matrix={confusion_matrix(y_test, y_predict)}")

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
print(f"accuracy_score={accuracy_score(y_test, y_predict)}\n\
precision_score={precision_score(y_test, y_predict)}\n\
recall_score={recall_score(y_test, y_predict)}\n\
f1_score={f1_score(y_test, y_predict)}")

# %% [markdown]
# ## Random Forest (Stratified K-Fold Cross Validation:層化K分割交差検証)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
# StratifiedKFoldの設定
skf = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 1234)

# %%
#　標準化の設定
ss_kfold = StandardScaler()

# %%
f1 = cross_val_score(clf, X, y, cv=skf, scoring='f1')

# %%
f1

# %%
f1.mean()

# %%
accuracy = cross_val_score(clf, X, y, cv=skf, scoring='accuracy')

# %%
accuracy

# %%
accuracy.mean()

# %%
recall = cross_val_score(clf, X, y, cv=skf, scoring='recall')

# %%
recall

# %%
recall.mean()

# %%
precision = cross_val_score(clf, X, y, cv=skf, scoring='precision')
precision

# %%
precision.mean()

# %%
## Grid Search with Cross Validation

# %% [markdown]
# ## Grid Search with Cross Validation

# %%
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the research paper
param_grid = {
    'n_estimators': [10, 20, 30, 50, 100, 300],
    'max_features': ['sqrt', 'log2', 'auto', None],
    'max_depth': [10, 20, 30, 40, 50, None]
}
# Instantiate the grid search model
clf = RandomForestClassifier(random_state = 1234)
grid_search = GridSearchCV(estimator = clf, param_grid = param_grid, cv = skf, scoring='f1')

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# %%
grid_search.best_params_

# %%
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    errors = abs(predictions - test_labels)
    mape = 100 * np.mean(errors / test_labels)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy

# %%
import numpy as np
best_grid = grid_search.best_estimator_
grid_accuracy = evaluate(best_grid, X_test, y_test)

# %%
df_result = grid_search.cv_results_

# %%
df_result

# %%
import pickle
with open('/content/drive/MyDrive/Colab Notebooks/cv_H_result.pkl', 'wb') as fp:
  pickle.dump(df_result, fp)

# %%
print(best_grid)

# %%
#テストデータに対する予測
y_pred = best_grid.predict(X_test)
#正解率の表示
print(f"accuracy_score={accuracy_score(y_test, y_pred)}\n\
precision_score={precision_score(y_test, y_pred)}\n\
recall_score={recall_score(y_test, y_pred)}\n\
f1_score={f1_score(y_test, y_pred)}")

# %% [markdown]
# ## Random Search Training

# %%
from pprint import pprint
from sklearn.model_selection import RandomizedSearchCV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
pprint(random_grid)

# %%
# Instantiate the grid search model
clf = RandomForestClassifier(random_state = 1234)
clf_random = RandomizedSearchCV(estimator = clf, param_distributions = random_grid, n_iter = 100, cv = skf, scoring='f1')

# Fit the grid search to the data
clf_random.fit(X_train, y_train)

# %%
clf_random.best_params_

# %%
best_random = clf_random.best_estimator_

# %%
df_rand_result = clf_random.cv_results_
import pickle
with open('/content/drive/MyDrive/Colab Notebooks/cv_rand_H_result.pkl', 'wb') as fp:
  pickle.dump(df_rand_result, fp)

# %%
#テストデータに対する予測
y_pred = best_random.predict(X_test)
#正解率の表示
print(f"accuracy_score={accuracy_score(y_test, y_pred)}\n\
precision_score={precision_score(y_test, y_pred)}\n\
recall_score={recall_score(y_test, y_pred)}\n\
f1_score={f1_score(y_test, y_pred)}")
